# %% [markdown]
# 1. What is hypothesis testing in statistics?
# -->Hypothesis testing is a statistical method used to make inferences or draw conclusions about a population based on sample data. It helps determine whether there is enough evidence to support a specific claim or hypothesis about a population parameter.
#
# Steps in Hypothesis Testing:
# Formulate Hypotheses:
#
# Null Hypothesis (H₀): Assumes no effect or no difference (status quo).
#
# Alternative Hypothesis (H₁ or Ha): Represents what we are trying to prove (a significant effect or difference).
#
# Set the Significance Level (α):
#
# Typically, α = 0.05 (5%) is chosen, meaning we accept a 5% risk of rejecting the null hypothesis when it is true.
#
# Select the Appropriate Test:
#
# Based on the data type and distribution, tests like t-test, chi-square test, ANOVA, or z-test are used.
#
# Compute the Test Statistic:
#
# The test statistic (like t-score or z-score) is calculated from the sample data to compare against a critical value.
#
# Make a Decision:
#
# Compare the p-value (probability of obtaining the observed results under H₀) with α.
#
# If p-value ≤ α: Reject H₀ (significant evidence for H₁).
#
# If p-value > α: Fail to reject H₀ (not enough evidence for H₁).
#
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
# -->The null hypothesis (H₀) and the alternative hypothesis (H₁ or Ha) are the two key components of hypothesis testing in statistics.
#
# 1. Null Hypothesis (H₀)
# It represents the default assumption or the status quo.
#
# It states that there is no effect, no difference, or no relationship in the population.
#
# The goal of hypothesis testing is to find evidence to reject H₀.
#
# ✅ Example:
# A company claims that its new weight-loss supplement has no effect.
#
# H₀: The supplement has no impact on weight loss.
#
# 2. Alternative Hypothesis (H₁ or Ha)
# It is the opposite of H₀ and represents what we want to prove.
#
# It states that there is an effect, difference, or relationship.
#
# If strong evidence is found, we reject H₀ in favor of H₁.
#
# ✅ Example:
# If researchers believe the supplement does help in weight loss, then:
#
# H₁: The supplement leads to weight loss.
#
# 3. What is the significance level in hypothesis testing, and why is it important?
# -->Significance Level (α) in Hypothesis Testing
# The significance level (α) is the threshold used to determine whether to reject the null hypothesis (H₀) in hypothesis testing. It represents the probability of making a Type I error, which occurs when we reject a true null hypothesis.
#
# Why is Significance Level Important?
# Controls the Probability of False Positives (Type I Error)
#
# A lower α reduces the chances of mistakenly rejecting H₀ when it is actually true.
#
# Determines Decision Making
#
# If the p-value (calculated probability) is less than or equal to α, we reject H₀.
#
# If the p-value is greater than α, we fail to reject H₀.
#
# Balances Accuracy & Sensitivity
#
# A very low α (e.g., 0.01) makes the test more strict, reducing false positives but increasing the chance of missing a real effect (Type II error).
#
# A higher α (e.g., 0.10) makes it easier to detect real effects but increases false positives.
#
# 4. What does a P-value represent in hypothesis testing?
# -->What is a P-Value in Hypothesis Testing?
# The p-value (probability value) is a measure of how much evidence we have against the null hypothesis (H₀). It tells us the probability of obtaining a test result at least as extreme as the one observed, assuming that H₀ is true.
#
# How to Interpret the P-Value?
# Small P-Value (≤ α) → Reject H₀
#
# There is strong evidence against the null hypothesis.
#
# The alternative hypothesis (H₁) is likely true.
#
# Large P-Value (> α) → Fail to Reject H₀
#
# There is not enough evidence to reject H₀.
#
# The result could have occurred by random chance.
#
# 5. How do you interpret the P-value in hypothesis testing?
# -->Interpreting the P-Value in Hypothesis Testing
# The p-value represents the probability of obtaining a result at least as extreme as the observed data, assuming that the null hypothesis (H₀) is true. It helps us decide whether to reject or fail to reject H₀.
#
# Key Interpretations of P-Value
# Small P-Value (≤ α) → Reject H₀
#
# There is strong evidence against the null hypothesis.
#
# The alternative hypothesis (H₁) is likely true.
#
# The results are statistically significant.
#
# Large P-Value (> α) → Fail to Reject H₀
#
# There is not enough evidence to reject H₀.
#
# The observed results could have happened by random chance.
#
# The results are not statistically significant.
#
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
# -->Type I and Type II Errors in Hypothesis Testing
# When performing hypothesis testing, we make decisions based on sample data, which can sometimes lead to errors. These errors are classified as Type I and Type II errors.
#
# 1. Type I Error (False Positive)
# Occurs when we reject a true null hypothesis (H₀).
#
# It means we conclude there is an effect when there isn't one.
#
# The probability of making a Type I error is α (significance level).
#
# 📌 Example:
# A company tests whether a new drug reduces blood pressure.
#
# H₀: The drug has no effect.
#
# H₁: The drug lowers blood pressure.
#
# If we reject H₀ when it is actually true, we conclude the drug works when it doesn’t.
#
# 🔹 Consequences: Wasting resources on an ineffective drug.
#
# 2. Type II Error (False Negative)
# Occurs when we fail to reject a false null hypothesis (H₀).
#
# It means we conclude there is no effect when there actually is one.
#
# The probability of making a Type II error is β (related to test power, 1 - β).
#
# 📌 Example:
# A manufacturing company tests if a new machine produces fewer defective products.
#
# H₀: The new machine is not better.
#
# H₁: The new machine produces fewer defects.
#
# If we fail to reject H₀ when it is false, we miss out on an improvement.
#
# 🔹 Consequences: Losing the opportunity to adopt a better process.
#
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
# -->One-Tailed vs. Two-Tailed Test in Hypothesis Testing
# In hypothesis testing, the choice between a one-tailed and a two-tailed test depends on the research question and the direction of the effect being tested.
#
# 1. One-Tailed Test (Directional Test)
# Tests for an effect in only one direction (either greater than or less than).
#
# The alternative hypothesis (H₁) specifies whether the parameter is greater or smaller than the null hypothesis (H₀).
#
# The rejection region is only on one side of the distribution.
#
# Examples of One-Tailed Tests:
# ✅ Right-Tailed Test (H₁: μ > μ₀)
#
# Example: Checking if a new fertilizer increases plant growth.
#
# H₀: The fertilizer has no effect.
#
# H₁: The fertilizer increases plant growth.
#
# ✅ Left-Tailed Test (H₁: μ < μ₀)
#
# Example: Testing if a diet reduces blood sugar levels.
#
# H₀: The diet has no effect.
#
# H₁: The diet reduces blood sugar.
#
# 📌 Advantage: More statistical power (higher chance of detecting an effect if it exists).
# 📌 Disadvantage: If the effect is in the opposite direction, we miss it.
#
# 2. Two-Tailed Test (Non-Directional Test)
# Tests for an effect in both directions (greater or smaller).
#
# The alternative hypothesis (H₁) states that the parameter is different from the null hypothesis (H₀) but does not specify a direction.
#
# The rejection region is on both sides of the distribution.
#
# Example of a Two-Tailed Test:
# Checking if a new medicine has an effect (either increasing or decreasing blood pressure).
#
# H₀: The medicine has no effect on blood pressure.
#
# H₁: The medicine changes blood pressure (could increase or decrease).
#
# 📌 Advantage: Detects any significant difference.
# 📌 Disadvantage: Requires a larger sample size to detect the effect
#
# 8. What is the Z-test, and when is it used in hypothesis testing?
# -->A Z-test is a statistical test used to determine whether there is a significant difference between a sample and a population, or between two samples, when the population variance is known and the data follows a normal distribution.
#
# When is the Z-Test Used?
# A Z-test is appropriate when:
# ✅ The sample size is large (n ≥ 30) (Central Limit Theorem applies).
# ✅ The population standard deviation (σ) is known.
# ✅ The data is normally distributed (or approximately normal for large samples).
#
# Types of Z-Tests
# 1️⃣ One-Sample Z-Test
#
# Compares the sample mean to a known population mean.
#
# Example: Checking if the average height of students in a university differs from the national average.
#
# 2️⃣ Two-Sample Z-Test
#
# Compares the means of two independent samples.
#
# Example: Comparing the average salaries of employees in two different companies.
#
# 3️⃣ Z-Test for Proportions
#
# Used when comparing population proportions.
#
# Example: Testing if the proportion of defective products in two factories is the same.
#
# Z-Test Formula
# For a one-sample Z-test:
#
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = Sample mean
#
# 𝜇
# μ = Population mean
#
# 𝜎
# σ = Population standard deviation
#
# 𝑛
# n = Sample size
#
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
# --> What is the Z-Score?
# The Z-score (standard score) measures how many standard deviations an observation is away from the mean. It helps determine whether a sample mean significantly differs from the population mean.
#
# Z-Score Formula:
# For a single data point:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# For a sample mean:
#
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# Where:
#
# 𝑋
# X = Individual data point
#
# 𝑋
# ˉ
# X
# ˉ
#   = Sample mean
#
# 𝜇
# μ = Population mean
#
# 𝜎
# σ = Population standard deviation
#
# 𝑛
# n = Sample size
#
# What Does the Z-Score Represent?
# 𝑍
# =
# 0
# Z=0 → The data point is equal to the mean.
#
# 𝑍
# >
# 0
# Z>0 → The data point is above the mean.
#
# 𝑍
# <
# 0
# Z<0 → The data point is below the mean.
#
# Higher |Z| values indicate that the data point is further from the mean (more unusual).
#
# Example Calculation:
# If a student scores 85 on a test where the class average is 75 and the standard deviation is 10, the Z-score is:
#
# 𝑍
# =
# 85
# −
# 75
# 10
# =
# 1.0
# Z=
# 10
# 85−75
# ​
#  =1.0
# 🔹 This means the student scored 1 standard deviation above the mean.
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
# -->What is the T-Distribution & When to Use It?
# What is the T-Distribution?
# The T-distribution (Student’s t-distribution) is a probability distribution that is similar to the normal distribution but has fatter tails, meaning it accounts for more variability in small sample sizes. It is used when estimating the population mean from a small sample where the population standard deviation (σ) is unknown.
#
# When Should You Use the T-Distribution Instead of the Normal Distribution?
# Use the T-distribution when:
# ✅ Sample size is small (n < 30).
# ✅ Population standard deviation (σ) is unknown (so we estimate it using the sample standard deviation, s).
# ✅ Data is normally distributed or approximately normal.
#
# Use the Z-distribution when:
# ✅ Sample size is large (n ≥ 30).
# ✅ Population standard deviation (σ) is known.
# ✅ Data is normally distributed.
#
# T-Score Formula:
# 𝑇
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝑠
# /
# 𝑛
# T=
# s/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = Sample mean
#
# 𝜇
# μ = Population mean
#
# 𝑠
# s = Sample standard deviation
#
# 𝑛
# n = Sample size
#
# The T-distribution depends on degrees of freedom (df), which is given by:
#
# 𝑑
# 𝑓
# =
# 𝑛
# −
# 1
# df=n−1
# A lower sample size results in a wider t-distribution, meaning more uncertainty in estimates.
#
# 11. What is the difference between a Z-test and a T-test?
# -->Difference Between Z-Test and T-Test
# Both Z-test and T-test are statistical tests used to compare sample data with a population or between two groups. The key difference lies in the sample size and whether the population standard deviation (σ) is known.
#
# Key Differences:
# Feature	Z-Test	T-Test
# Sample Size (n)	Large (n ≥ 30)	Small (n < 30)
# Population Standard Deviation (σ)	Known	Unknown (use sample standard deviation s)
# Distribution Used	Normal (Z) Distribution	T-Distribution (fatter tails)
# Shape of Distribution	Fixed	Changes based on degrees of freedom (df = n - 1)
# Use Case	Large samples where σ is known	Small samples where σ is unknown
# Example	Comparing the average IQ of students with a national average	Testing if a new drug lowers blood pressure in a small group
# When to Use Each Test?
# ✅ Use a Z-Test if:
#
# The sample size is large (n ≥ 30).
#
# The population standard deviation (σ) is known.
#
# The data is normally distributed.
#
# ✅ Use a T-Test if:
#
# The sample size is small (n < 30).
#
# The population standard deviation (σ) is unknown.
#
# The data is normally distributed or approximately normal.
#
# Formulas for Each Test
# Z-Test Formula:
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# 𝑋
# ˉ
# X
# ˉ
#   = Sample mean
#
# 𝜇
# μ = Population mean
#
# 𝜎
# σ = Population standard deviation
#
# 𝑛
# n = Sample size
#
# T-Test Formula:
# 𝑇
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝑠
# /
# 𝑛
# T=
# s/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# 𝑠
# s = Sample standard deviation (used instead of σ)
#
# Other terms are the same as in the Z-test formula
#
# 12. What is the T-test, and how is it used in hypothesis testing?
# -->What is the T-Test?
# The T-test is a statistical method used to determine if there is a significant difference between the means of two groups or between a sample mean and a population mean. It is used when the sample size is small (n < 30) and the population standard deviation (σ) is unknown.
#
# How is the T-Test Used in Hypothesis Testing?
# 1️⃣ State the Hypotheses:
#
# Null Hypothesis (H₀): There is no difference between the means.
#
# Alternative Hypothesis (H₁): There is a difference between the means.
#
# 2️⃣ Choose the Type of T-Test:
#
# One-Sample T-Test: Compares a sample mean to a known population mean.
#
# Independent (Two-Sample) T-Test: Compares the means of two independent groups.
#
# Paired T-Test: Compares the means of two related samples (before & after study).
#
# 3️⃣ Calculate the T-Statistic:
#
# 𝑇
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝑠
# /
# 𝑛
# T=
# s/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# 𝑋
# ˉ
# X
# ˉ
#   = Sample mean
#
# 𝜇
# μ = Population mean
#
# 𝑠
# s = Sample standard deviation
#
# 𝑛
# n = Sample size
#
# 4️⃣ Determine Degrees of Freedom (df):
#
# 𝑑
# 𝑓
# =
# 𝑛
# −
# 1
# df=n−1
# 5️⃣ Find the Critical Value & Compare the T-Statistic:
#
# Use a T-table or software to find the critical value at α = 0.05 or 0.01.
#
# If |T-statistic| > Critical Value, reject H₀ (significant difference).
#
# Types of T-Tests & When to Use Them
# Type	Use Case	Example
# One-Sample T-Test	Compare sample mean to population mean	Checking if a class's average test score differs from the national average
# Independent T-Test	Compare two unrelated groups	Comparing male vs. female test scores
# Paired T-Test	Compare two related samples	Before vs. after results in a weight loss study
#
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
# -->Relationship Between Z-Test and T-Test in Hypothesis Testing
# The Z-test and T-test are both statistical methods used in hypothesis testing to determine if there is a significant difference between a sample and a population or between two groups. They are closely related but differ in their assumptions and when they are used.
#
# 1️⃣ Similarities Between Z-Test and T-Test
# ✅ Both are used to compare sample means to a population mean or between two groups.
# ✅ Both involve calculating a test statistic to compare against a critical value.
# ✅ Both follow a similar formula but use different distributions (Z vs. T).
# ✅ Both help in accepting or rejecting the null hypothesis (H₀).
#
# 2️⃣ Key Differences Between Z-Test and T-Test
# Feature	Z-Test	T-Test
# Sample Size	Large (n ≥ 30)	Small (n < 30)
# Population Standard Deviation (σ)	Known	Unknown (use sample standard deviation s)
# Distribution Used	Normal (Z) Distribution	T-Distribution (wider tails)
# Degrees of Freedom (df)	Not needed	df = n - 1
# Shape of Distribution	Fixed (bell curve)	Varies with sample size (fatter tails for small n)
# Use Case	Large sample size with known σ	Small sample size with unknown σ
# 3️⃣ Relationship Between the Two Tests
# 🔹 T-distribution Approximates the Z-distribution:
#
# When the sample size is small, the T-distribution is used because it accounts for more variability.
#
# As n increases, the T-distribution becomes almost identical to the Z-distribution.
#
# When n ≥ 30, the T-test results are nearly the same as the Z-test, so the Z-test can be used.
#
# 🔹 Z-Test is a Special Case of T-Test:
#
# If we know the population standard deviation (σ), the T-test simplifies into a Z-test.
#
# If n is large, the sample standard deviation (s) is close to σ, so we can use the Z-test instead of the T-test.
#
# 4️⃣ Example: When to Use Each Test
# 📌 Scenario 1 (Z-Test):
# A company claims that the average weight of its product is 500g. A random sample of 50 products has an average weight of 495g, and the population standard deviation is known (σ = 10g). Since n ≥ 30 and σ is known, use a Z-test.
#
# 📌 Scenario 2 (T-Test):
# A new medication is tested on 15 patients. Their average blood pressure is 120 mmHg, with a sample standard deviation of 8 mmHg. Since n < 30 and σ is unknown, use a T-test.
#
# 5️⃣ Conclusion
# Use a Z-test when σ is known and n is large.
#
# Use a T-test when σ is unknown or n is small.
#
# As n increases, the T-test approximates the Z-test, making them mathematically related.
#
# 14. What is a confidence interval, and how is it used to interpret statistical results?
# -->What is a Confidence Interval (CI)?
# A confidence interval (CI) is a range of values that is likely to contain the true population parameter (e.g., mean, proportion) with a certain level of confidence. It provides an estimate of uncertainty in statistical results.
#
# For example, if a 95% confidence interval for the average height of students is (165 cm, 175 cm), it means we are 95% confident that the true average height of all students falls within this range.
#
# How is a Confidence Interval Used?
# 1️⃣ Estimate the Population Parameter
#
# Instead of a single value (point estimate), we get a range of possible values.
#
# 2️⃣ Measure the Precision of an Estimate
#
# A narrower CI → More precise estimate (larger sample size).
#
# A wider CI → Less precise estimate (smaller sample size or more variability).
#
# 3️⃣ Hypothesis Testing
#
# If the CI includes the null hypothesis value (e.g., population mean μ₀), we fail to reject H₀.
#
# If the CI does not include μ₀, we reject H₀, meaning a significant difference exists.
#
# Formula for Confidence Interval
# For a population mean (
# 𝜇
# μ), the CI is calculated as:
#
# 𝐶
# 𝐼
# =
# 𝑋
# ˉ
# ±
# (
# 𝑍
#  or
# 𝑇
# )
# ×
# 𝑠
# 𝑛
# CI=
# X
# ˉ
#  ±(Z or T)×
# n
# ​
#
# s
# ​
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = Sample mean
#
# 𝑍
#  or
# 𝑇
# Z or T = Critical value from the Z-table (large samples) or T-table (small samples)
#
# 𝑠
# s = Sample standard deviation
#
# 𝑛
# n = Sample size
#
# Example: 95% Confidence Interval Calculation
# A sample of 30 students has an average test score of 70 with a standard deviation of 10. Find the 95% confidence interval for the population mean.
#
# 🔹 Step 1: Identify values
#
# 𝑋
# ˉ
# =
# 70
# X
# ˉ
#  =70,
# 𝑠
# =
# 10
# s=10,
# 𝑛
# =
# 30
# n=30,
# 𝑍
# 0.05
# /
# 2
# =
# 1.96
# Z
# 0.05/2
# ​
#  =1.96 (for 95% CI)
#
# 🔹 Step 2: Compute the margin of error
#
# 𝑀
# 𝐸
# =
# 1.96
# ×
# 10
# 30
# =
# 3.57
# ME=1.96×
# 30
# ​
#
# 10
# ​
#  =3.57
# 🔹 Step 3: Compute the CI
#
# 𝐶
# 𝐼
# =
# 70
# ±
# 3.57
# =
# (
# 66.43
# ,
# 73.57
# )
# CI=70±3.57=(66.43,73.57)
# 🔹 Interpretation:
# We are 95% confident that the true population mean lies between 66.43 and 73.57.
#
# 15. What is the margin of error, and how does it affect the confidence interval*
# -->What is the Margin of Error (MoE)?
# The margin of error (MoE) is the amount by which the sample estimate may vary due to random sampling. It represents the uncertainty in a confidence interval (CI) and helps determine how precise our estimate is.
#
# It is calculated as:
#
# 𝑀
# 𝑜
# 𝐸
# =
# (
# 𝑍
#  or
# 𝑇
# )
# ×
# 𝑠
# 𝑛
# MoE=(Z or T)×
# n
# ​
#
# s
# ​
#
# Where:
#
# 𝑍
#  or
# 𝑇
# Z or T = Critical value from the Z-table (large samples) or T-table (small samples)
#
# 𝑠
# s = Sample standard deviation
#
# 𝑛
# n = Sample size
#
# How Does the Margin of Error Affect the Confidence Interval?
# 1️⃣ Larger Margin of Error → Wider Confidence Interval
#
# More uncertainty in the estimate.
#
# Caused by small sample size or high variability.
#
# 2️⃣ Smaller Margin of Error → Narrower Confidence Interval
#
# More precise estimate.
#
# Caused by large sample size or low variability.
#
# Example: Margin of Error Calculation
# A sample of 50 students has an average test score of 80, with a standard deviation of 12. Find the 95% margin of error.
#
# 🔹 Step 1: Identify values
#
# 𝑠
# =
# 12
# s=12,
# 𝑛
# =
# 50
# n=50,
# 𝑍
# 0.05
# /
# 2
# =
# 1.96
# Z
# 0.05/2
# ​
#  =1.96 (for 95% CI)
#
# 🔹 Step 2: Compute MoE
#
# 𝑀
# 𝑜
# 𝐸
# =
# 1.96
# ×
# 12
# 50
# =
# 3.32
# MoE=1.96×
# 50
# ​
#
# 12
# ​
#  =3.32
# 🔹 Interpretation:
# The estimate may vary by ±3.32 points, meaning the confidence interval is (76.68, 83.32).
#
# 16.  How is Bayes' Theorem used in statistics, and what is its significance?
# -->Bayes' Theorem in Statistics
# Bayes' Theorem is a fundamental concept in probability and statistics that describes how to update the probability of an event based on new evidence. It helps in revising beliefs when given additional information.
#
# The formula for Bayes' Theorem is:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Where:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B) = Probability of event A occurring given that event B has occurred (Posterior Probability)
#
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A) = Probability of event B occurring given A (Likelihood)
#
# 𝑃
# (
# 𝐴
# )
# P(A) = Probability of event A (Prior Probability)
#
# 𝑃
# (
# 𝐵
# )
# P(B) = Probability of event B (Total Probability)
#
# How is Bayes’ Theorem Used in Statistics?
# 1️⃣ Medical Testing (False Positives & False Negatives)
#
# Helps determine the real probability of a disease given a positive test result.
#
# Example: If a COVID-19 test is 95% accurate, but the disease is rare (1 in 10,000 people), Bayes' Theorem helps compute the true chance of being infected after testing positive.
#
# 2️⃣ Spam Filtering (Email Classification)
#
# Used in Naïve Bayes Classifiers to classify emails as spam or not spam based on words in the email.
#
# 3️⃣ Machine Learning & Artificial Intelligence
#
# Used in probabilistic models like Bayesian Networks and Naïve Bayes classifiers for text classification, recommendation systems, etc.
#
# 4️⃣ Predictive Analytics & Decision-Making
#
# Helps in fraud detection, credit risk analysis, and customer behavior prediction by updating probabilities as new data is collected.
#
# Example: Medical Testing (False Positives & Bayes’ Theorem)
# 📌 Suppose:
#
# 1% of a population has a disease (
# 𝑃
# (
# 𝐴
# )
# =
# 0.01
# P(A)=0.01).
#
# A test is 95% accurate (correctly detects disease 95% of the time).
#
# However, 5% of healthy people also test positive (false positive rate 5%).
#
# What is the probability that a person actually has the disease if they tested positive?
# Using Bayes’ Theorem:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# =
# 0.95
# ×
# 0.01
# (
# 0.95
# ×
# 0.01
# )
# +
# (
# 0.05
# ×
# 0.99
# )
# =
# (0.95×0.01)+(0.05×0.99)
# 0.95×0.01
# ​
#
# =
# 0.0095
# 0.0095
# +
# 0.0495
# =
# 0.0095
# 0.059
# =
# 0.161
# =
# 0.0095+0.0495
# 0.0095
# ​
#  =
# 0.059
# 0.0095
# ​
#  =0.161
# 🔹 Interpretation: Even if you test positive, the actual chance of having the disease is only 16.1%, because false positives are common when the disease is rare!
#
# 17. Bayes' Theorem in Statistics
# Bayes' Theorem is a fundamental concept in probability and statistics that describes how to update the probability of an event based on new evidence. It helps in revising beliefs when given additional information.
#
# The formula for Bayes' Theorem is:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Where:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B) = Probability of event A occurring given that event B has occurred (Posterior Probability)
#
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A) = Probability of event B occurring given A (Likelihood)
#
# 𝑃
# (
# 𝐴
# )
# P(A) = Probability of event A (Prior Probability)
#
# 𝑃
# (
# 𝐵
# )
# P(B) = Probability of event B (Total Probability)
#
# How is Bayes’ Theorem Used in Statistics?
# 1️⃣ Medical Testing (False Positives & False Negatives)
#
# Helps determine the real probability of a disease given a positive test result.
#
# Example: If a COVID-19 test is 95% accurate, but the disease is rare (1 in 10,000 people), Bayes' Theorem helps compute the true chance of being infected after testing positive.
#
# 2️⃣ Spam Filtering (Email Classification)
#
# Used in Naïve Bayes Classifiers to classify emails as spam or not spam based on words in the email.
#
# 3️⃣ Machine Learning & Artificial Intelligence
#
# Used in probabilistic models like Bayesian Networks and Naïve Bayes classifiers for text classification, recommendation systems, etc.
#
# 4️⃣ Predictive Analytics & Decision-Making
#
# Helps in fraud detection, credit risk analysis, and customer behavior prediction by updating probabilities as new data is collected.
#
# Example: Medical Testing (False Positives & Bayes’ Theorem)
# 📌 Suppose:
#
# 1% of a population has a disease (
# 𝑃
# (
# 𝐴
# )
# =
# 0.01
# P(A)=0.01).
#
# A test is 95% accurate (correctly detects disease 95% of the time).
#
# However, 5% of healthy people also test positive (false positive rate 5%).
#
# What is the probability that a person actually has the disease if they tested positive?
# Using Bayes’ Theorem:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# =
# 0.95
# ×
# 0.01
# (
# 0.95
# ×
# 0.01
# )
# +
# (
# 0.05
# ×
# 0.99
# )
# =
# (0.95×0.01)+(0.05×0.99)
# 0.95×0.01
# ​
#
# =
# 0.0095
# 0.0095
# +
# 0.0495
# =
# 0.0095
# 0.059
# =
# 0.161
# =
# 0.0095+0.0495
# 0.0095
# ​
#  =
# 0.059
# 0.0095
# ​
#  =0.161
# 🔹 Interpretation: Even if you test positive, the actual chance of having the disease is only 16.1%, because false positives are common when the disease is rare!
#
# 17. What is the Chi-square distribution, and when is it used*
# -->What is the Chi-Square Distribution?
# The Chi-Square (χ²) distribution is a probability distribution used to analyze categorical data. It is derived from the sum of the squares of independent standard normal variables and is used for testing relationships between categorical variables and population variance.
#
# The Chi-Square statistic is calculated as:
#
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# −
# 𝐸
# )
# 2
# 𝐸
# χ
# 2
#  =∑
# E
# (O−E)
# 2
#
# ​
#
# Where:
#
# O = Observed frequency
#
# E = Expected frequency
#
# When is the Chi-Square Distribution Used?
# 1️⃣ Chi-Square Test for Independence
#
# Used to check if two categorical variables are related (e.g., Gender vs. Preference).
#
# Example: Does smoking status depend on age group?
#
# 2️⃣ Chi-Square Goodness-of-Fit Test
#
# Checks whether an observed distribution matches an expected distribution.
#
# Example: Do customers prefer all flavors of ice cream equally?
#
# 3️⃣ Chi-Square Test for Variance
#
# Used to test if a population variance is equal to a known value.
#
# Example: Is the variance in exam scores consistent with historical data
#
# 18. What is the Chi-square goodness of fit test, and how is it applied?
# -->What is the Chi-Square Goodness-of-Fit Test?
# The Chi-Square Goodness-of-Fit Test is a statistical test used to determine whether an observed distribution of categorical data matches an expected distribution.
#
# It helps answer questions like:
#
# Do customers prefer all product colors equally?
#
# Does the number of students choosing different majors match historical data?
#
# Do dice rolls follow a fair uniform distribution?
#
# The test compares observed frequencies (
# 𝑂
# O) with expected frequencies (
# 𝐸
# E) using the Chi-Square statistic:
#
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# −
# 𝐸
# )
# 2
# 𝐸
# χ
# 2
#  =∑
# E
# (O−E)
# 2
#
# ​
#
# Where:
#
# O = Observed frequency
#
# E = Expected frequency
#
# How is the Chi-Square Goodness-of-Fit Test Applied?
# ✅ Step 1: Define the Hypotheses
#
# Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): The observed data follows the expected distribution.
#
# Alternative Hypothesis (
# 𝐻
# 𝐴
# H
# A
# ​
#  ): The observed data does not follow the expected distribution.
#
# ✅ Step 2: Collect Observed Data
# Example: A company sells a product in 4 colors (Red, Blue, Green, Yellow). They expect an equal proportion of sales
#
# 19. What is the F-distribution, and when is it used in hypothesis testing*
# -->What is the F-Distribution?
# The F-distribution is a continuous probability distribution used primarily in hypothesis testing for comparing variances between two samples. It is positively skewed and depends on two degrees of freedom:
#
# 𝑑
# 𝑓
# 1
# df
# 1
# ​
#   (numerator degrees of freedom)
#
# 𝑑
# 𝑓
# 2
# df
# 2
# ​
#   (denominator degrees of freedom)
#
# The F-distribution is often used in:
# 1️⃣ ANOVA (Analysis of Variance) – To compare means of multiple groups.
# 2️⃣ F-test for Variance Comparison – To test if two populations have the same variance.
# 3️⃣ Regression Analysis – To assess the significance of predictors.
#
# Formula for the F-Statistic
# 𝐹
# =
# 𝑆
# 1
# 2
# 𝑆
# 2
# 2
# F=
# S
# 2
# 2
# ​
#
# S
# 1
# 2
# ​
#
# ​
#
# Where:
#
# 𝑆
# 1
# 2
# S
# 1
# 2
# ​
#   = Variance of sample 1 (larger variance in the numerator).
#
# 𝑆
# 2
# 2
# S
# 2
# 2
# ​
#   = Variance of sample 2.
#
# If
# 𝐹
# F is significantly larger than 1, it suggests unequal variances.
#
# When is the F-Distribution Used in Hypothesis Testing?
# 1️⃣ F-Test for Equality of Variances
# Used to check if two populations have the same variance before applying a t-test.
#
# Hypotheses:
#
# 𝐻
# 0
# H
# 0
# ​
#  : The variances are equal (
# 𝑆
# 1
# 2
# =
# 𝑆
# 2
# 2
# S
# 1
# 2
# ​
#  =S
# 2
# 2
# ​
#  ).
#
# 𝐻
# 𝐴
# H
# A
# ​
#  : The variances are not equal (
# 𝑆
# 1
# 2
# ≠
# 𝑆
# 2
# 2
# S
# 1
# 2
# ​
#
# 
# =S
# 2
# 2
# ​
#  ).
#
# 👉 If F-value > critical F-value, reject
# 𝐻
# 0
# H
# 0
# ​
#  , meaning the variances are significantly different.
#
# 2️⃣ ANOVA (Analysis of Variance)
# Used to compare the means of three or more groups by analyzing their variances.
#
# Hypotheses:
#
# 𝐻
# 0
# H
# 0
# ​
#  : All group means are equal.
#
# 𝐻
# 𝐴
# H
# A
# ​
#  : At least one group mean is different.
#
# Formula:
#
# 𝐹
# =
# Variance between groups
# Variance within groups
# F=
# Variance within groups
# Variance between groups
# ​
#
# 👉 If F-value is large, it suggests significant differences among groups.
#
# 20.  What is an ANOVA test, and what are its assumptions?
# -->What is an ANOVA Test?
# ANOVA (Analysis of Variance) is a statistical method used to compare the means of three or more groups to determine if at least one group mean is significantly different. It helps test whether observed differences are due to actual differences or just random variation.
#
# Types of ANOVA
# 1️⃣ One-Way ANOVA – Compares means across one independent variable (e.g., Exam scores of students from different schools).
# 2️⃣ Two-Way ANOVA – Compares means across two independent variables (e.g., Exam scores based on both school and teaching method).
# 3️⃣ Repeated Measures ANOVA – Compares means when the same subjects are measured multiple times (e.g., Blood pressure before, during, and after treatment).
#
# Formula for ANOVA Test (F-Statistic)
# 𝐹
# =
# Variance between groups
# Variance within groups
# F=
# Variance within groups
# Variance between groups
# ​
#
# Large F-value → Greater difference between groups → Likely significant.
#
# Small F-value → Groups have similar means → Likely not significant.
#
# Assumptions of ANOVA
# For ANOVA to be valid, these conditions must be met:
#
# ✅ 1. Independence
#
# Observations should be independent within and across groups.
#
# ✅ 2. Normality
#
# The data in each group should be approximately normally distributed (Checked using Shapiro-Wilk test or QQ plot).
#
# ✅ 3. Homogeneity of Variances (Homoscedasticity)
#
# The variance across groups should be roughly equal (Checked using Levene’s Test).
#
# 21. What are the different types of ANOVA tests?
# -->Types of ANOVA Tests
# ANOVA (Analysis of Variance) is used to compare the means of groups to determine if they are significantly different. There are several types of ANOVA based on the number of independent variables and whether the data is measured repeatedly.
#
# 1️⃣ One-Way ANOVA (Single Factor ANOVA)
# Purpose: Compares the means of three or more groups based on one independent variable.
#
# Example: Testing whether students from three different schools have the same average test scores.
#
# Hypotheses:
#
# 𝐻
# 0
# H
# 0
# ​
#  : All group means are equal.
#
# 𝐻
# 𝐴
# H
# A
# ​
#  : At least one group mean is different.
#
# 2️⃣ Two-Way ANOVA (Factorial ANOVA)
# Purpose: Compares means across two independent variables to see their individual and combined effects.
#
# Example: Studying how diet (low-carb, high-protein, vegan) and exercise type (cardio, strength training) affect weight loss.
#
# Hypotheses:
#
# 𝐻
# 0
# H
# 0
# ​
#  : No effect of either factor, and no interaction.
#
# 𝐻
# 𝐴
# H
# A
# ​
#  : At least one factor has a significant effect, or there's an interaction.
#
# Variants:
#
# Without Interaction: Tests only the individual effects of two factors.
#
# With Interaction: Tests whether the effect of one factor depends on another.
#
# 3️⃣ Repeated Measures ANOVA
# Purpose: Used when the same subjects are measured multiple times under different conditions.
#
# Example: Measuring a patient’s blood pressure before, during, and after medication treatment.
#
# Key Benefit: Controls for variability between subjects since the same individuals are tested repeatedly.
#
# 4️⃣ Mixed-Design ANOVA
# Purpose: Combines between-subjects (e.g., comparing different groups) and within-subjects (e.g., repeated measures) factors.
#
# Example: Testing the effect of exercise type (between-subjects: yoga vs. HIIT) and time (before vs. after training) on weight loss.
#
# 5️⃣ MANOVA (Multivariate Analysis of Variance)
# Purpose: A multivariate version of ANOVA that compares multiple dependent variables at once.
#
# Example: Studying how teaching method (lecture, online, hybrid) affects both math scores and reading scores simultaneously.
#
# Advantage: Reduces the risk of false positives (Type I errors) compared to multiple separate ANOVAs.
#
# 6️⃣ ANCOVA (Analysis of Covariance)
# Purpose: ANOVA that adjusts for covariates (control variables) that might influence the dependent variable.
#
# Example: Comparing exam scores across schools while controlling for students' prior academic performance.
#
# 22. What is the F-test, and how does it relate to hypothesis testing?
# -->What is the F-Test?
# The F-test is a statistical test that compares the variances of two populations or evaluates whether multiple group means are significantly different. It is based on the F-distribution and is widely used in hypothesis testing, especially in:
#
# Variance comparison tests (e.g., checking if two datasets have the same variance).
#
# Analysis of Variance (ANOVA) (e.g., comparing means of three or more groups).
#
# Regression analysis (e.g., determining if independent variables significantly explain variation in the dependent variable).
#
# Formula for the F-Statistic
# The F-statistic is calculated as:
#
# 𝐹
# =
# Variance of group 1
# Variance of group 2
# =
# 𝑆
# 1
# 2
# 𝑆
# 2
# 2
# F=
# Variance of group 2
# Variance of group 1
# ​
#  =
# S
# 2
# 2
# ​
#
# S
# 1
# 2
# ​
#
# ​
#
# Where:
#
# 𝑆
# 1
# 2
# S
# 1
# 2
# ​
#   = Variance of the first sample (larger variance in the numerator).
#
# 𝑆
# 2
# 2
# S
# 2
# 2
# ​
#   = Variance of the second sample.
#
# If
# 𝐹
# >
# 1
# F>1, it suggests that the first sample has greater variance than the second. If the F-value is significantly large, it may indicate unequal variances.
#
# How Does the F-Test Relate to Hypothesis Testing?
# The F-test follows a standard hypothesis testing framework:
#
# 1️⃣ Define Hypotheses
#
# Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): The variances (or means) are equal.
#
# Alternative Hypothesis (
# 𝐻
# 𝐴
# H
# A
# ​
#  ): The variances (or means) are different.
#
# 2️⃣ Calculate the F-statistic
#
# Compute sample variances and apply the F formula.
#
# 3️⃣ Compare with Critical F-Value or P-Value
#
# If
# 𝐹
# >
# 𝐹
# critical
# F>F
# critical
# ​
#  , reject
# 𝐻
# 0
# H
# 0
# ​
#  .
#
# Alternatively, if p-value < 0.05, reject
# 𝐻
# 0
# H
# 0
# ​
#  .
#
# Types of F-Tests in Hypothesis Testing
# 1️⃣ F-Test for Equality of Variances
#
# Determines if two populations have the same variance.
#
# Used before applying a t-test to check for homogeneity of variances.
#
# Example: Checking if two manufacturing processes have the same output variability.
#
# 2️⃣ F-Test in ANOVA (Analysis of Variance)
#
# Used to compare means of three or more groups by analyzing their variances.
#
# Example: Testing if students from three different schools have different average scores.
#
# 3️⃣ F-Test in Regression Analysis
#
# Assesses the overall significance of a regression model.
#
# Compares explained vs. unexplained variance.
#
# Example: Testing if advertising spend significantly affects sales.

# %%
#practical
#1.Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results ?
import numpy as np
from scipy import stats

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample Z-test.
    :param sample: List or array of sample data
    :param pop_mean: Known population mean
    :param pop_std: Known population standard deviation
    :param alpha: Significance level (default 0.05)
    :return: Z-score, p-value, and interpretation
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Interpret the results
    print(f"Sample Mean: {sample_mean}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the sample and population mean.")

# Example usage
sample_data = [52, 48, 50, 53, 47, 49, 51, 52, 50, 48]
population_mean = 50
population_std = 3
z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 50.0
# Z-score: 0.0000
# P-value: 1.0000
# Fail to reject the null hypothesis: No significant difference between the sample and population mean.

# %%
#2.Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python?
import numpy as np
from scipy import stats

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample Z-test.
    :param sample: List or array of sample data
    :param pop_mean: Known population mean
    :param pop_std: Known population standard deviation
    :param alpha: Significance level (default 0.05)
    :return: Z-score, p-value, and interpretation
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Interpret the results
    print(f"Sample Mean: {sample_mean}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the sample and population mean.")

# Simulate random data
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=50, scale=3, size=30)  # Mean=50, Std=3, Size=30
population_mean = 50
population_std = 3
z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 49.435559312446884
# Z-score: -1.0305
# P-value: 0.3028
# Fail to reject the null hypothesis: No significant difference between the sample and population mean.

# %%
#3.  Implement a one-sample Z-test using Python to compare the sample mean with the population mean?
import numpy as np
from scipy import stats

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample Z-test.
    :param sample: List or array of sample data
    :param pop_mean: Known population mean
    :param pop_std: Known population standard deviation
    :param alpha: Significance level (default 0.05)
    :return: Z-score, p-value, and interpretation
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Interpret the results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the sample and population mean.")

# Simulate random data for one-sample Z-test
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=50, scale=3, size=30)  # Mean=50, Std=3, Size=30
population_mean = 50
population_std = 3
z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 49.4356
# Z-score: -1.0305
# P-value: 0.3028
# Fail to reject the null hypothesis: No significant difference between the sample and population mean.

# %%
#4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot@
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    :param sample: List or array of sample data
    :param pop_mean: Known population mean
    :param pop_std: Known population standard deviation
    :param alpha: Significance level (default 0.05)
    :return: Z-score, p-value, and interpretation
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")

    if abs(z_score) > z_critical:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the sample and population mean.")

    # Visualization of decision region
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label="Standard Normal Distribution")

    # Shade rejection regions
    plt.fill_between(x, y, where=(x < -z_critical), color='red', alpha=0.5, label="Rejection Region")
    plt.fill_between(x, y, where=(x > z_critical), color='red', alpha=0.5)

    # Mark z-score
    plt.axvline(z_score, color='blue', linestyle='dashed', linewidth=2, label=f'Z-score: {z_score:.2f}')
    plt.axvline(-z_critical, color='black', linestyle='dotted', linewidth=2, label=f'Critical Value: ±{z_critical:.2f}')
    plt.axvline(z_critical, color='black', linestyle='dotted', linewidth=2)

    plt.title("Two-Tailed Z-Test Decision Region")
    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid()
    plt.show()

# Simulate random data for two-tailed Z-test
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=50, scale=3, size=30)  # Mean=50, Std=3, Size=30
population_mean = 50
population_std = 3
z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 49.4356
# Z-score: -1.0305
# P-value: 0.3028
# Fail to reject the null hypothesis: No significant difference between the sample and population mean.

# %%
#5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing?
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    :param sample: List or array of sample data
    :param pop_mean: Known population mean
    :param pop_std: Known population standard deviation
    :param alpha: Significance level (default 0.05)
    :return: Z-score, p-value, and interpretation
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")

    if abs(z_score) > z_critical:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the sample and population mean.")

    # Visualization of decision region
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label="Standard Normal Distribution")

    # Shade rejection regions
    plt.fill_between(x, y, where=(x < -z_critical), color='red', alpha=0.5, label="Rejection Region")
    plt.fill_between(x, y, where=(x > z_critical), color='red', alpha=0.5)

    # Mark z-score
    plt.axvline(z_score, color='blue', linestyle='dashed', linewidth=2, label=f'Z-score: {z_score:.2f}')
    plt.axvline(-z_critical, color='black', linestyle='dotted', linewidth=2, label=f'Critical Value: ±{z_critical:.2f}')
    plt.axvline(z_critical, color='black', linestyle='dotted', linewidth=2)

    plt.title("Two-Tailed Z-Test Decision Region")
    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid()
    plt.show()

def visualize_type1_type2_errors(alpha=0.05, beta=0.2):
    """
    Visualize Type 1 and Type 2 errors in hypothesis testing.
    :param alpha: Significance level (Type 1 error probability)
    :param beta: Type 2 error probability
    """
    x = np.linspace(-4, 4, 1000)
    y_null = stats.norm.pdf(x, 0, 1)  # Null distribution (H0)
    y_alt = stats.norm.pdf(x, 2, 1)  # Alternative distribution (H1, shifted mean)

    z_critical = stats.norm.ppf(1 - alpha)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y_null, label="Null Hypothesis (H0)", color='blue')
    plt.plot(x, y_alt, label="Alternative Hypothesis (H1)", color='green')

    # Shade Type 1 error (alpha region)
    plt.fill_between(x, y_null, where=(x > z_critical), color='red', alpha=0.5, label="Type 1 Error (α)")

    # Shade Type 2 error (beta region)
    beta_region = x < z_critical
    plt.fill_between(x, y_alt, where=beta_region, color='orange', alpha=0.5, label="Type 2 Error (β)")

    plt.axvline(z_critical, color='black', linestyle='dotted', linewidth=2, label=f'Critical Value: {z_critical:.2f}')
    plt.title("Type 1 and Type 2 Errors in Hypothesis Testing")
    plt.xlabel("Test Statistic")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid()
    plt.show()

# Simulate random data for two-tailed Z-test
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=50, scale=3, size=30)  # Mean=50, Std=3, Size=30
population_mean = 50
population_std = 3
z_test(sample_data, population_mean, population_std)

# Visualize Type 1 and Type 2 Errors
visualize_type1_type2_errors()
# Out:
# Sample Mean: 49.4356
# Z-score: -1.0305
# P-value: 0.3028
# Fail to reject the null hypothesis: No significant difference between the sample and population mean.

# %%
#6. Write a Python program to perform an independent T-test and interpret the results@
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    :param sample: List or array of sample data
    :param pop_mean: Known population mean
    :param pop_std: Known population standard deviation
    :param alpha: Significance level (default 0.05)
    :return: Z-score, p-value, and interpretation
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")

    if abs(z_score) > z_critical:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the sample and population mean.")

    # Visualization of decision region
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label="Standard Normal Distribution")

    # Shade rejection regions
    plt.fill_between(x, y, where=(x < -z_critical), color='red', alpha=0.5, label="Rejection Region")
    plt.fill_between(x, y, where=(x > z_critical), color='red', alpha=0.5)

    # Mark z-score
    plt.axvline(z_score, color='blue', linestyle='dashed', linewidth=2, label=f'Z-score: {z_score:.2f}')
    plt.axvline(-z_critical, color='black', linestyle='dotted', linewidth=2, label=f'Critical Value: ±{z_critical:.2f}')
    plt.axvline(z_critical, color='black', linestyle='dotted', linewidth=2)

    plt.title("Two-Tailed Z-Test Decision Region")
    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid()
    plt.show()

def visualize_type1_type2_errors(alpha=0.05, beta=0.2):
    """
    Visualize Type 1 and Type 2 errors in hypothesis testing.
    :param alpha: Significance level (Type 1 error probability)
    :param beta: Type 2 error probability
    """
    x = np.linspace(-4, 4, 1000)
    y_null = stats.norm.pdf(x, 0, 1)  # Null distribution (H0)
    y_alt = stats.norm.pdf(x, 2, 1)  # Alternative distribution (H1, shifted mean)

    z_critical = stats.norm.ppf(1 - alpha)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y_null, label="Null Hypothesis (H0)", color='blue')
    plt.plot(x, y_alt, label="Alternative Hypothesis (H1)", color='green')

    # Shade Type 1 error (alpha region)
    plt.fill_between(x, y_null, where=(x > z_critical), color='red', alpha=0.5, label="Type 1 Error (α)")

    # Shade Type 2 error (beta region)
    beta_region = x < z_critical
    plt.fill_between(x, y_alt, where=beta_region, color='orange', alpha=0.5, label="Type 2 Error (β)")

    plt.axvline(z_critical, color='black', linestyle='dotted', linewidth=2, label=f'Critical Value: {z_critical:.2f}')
    plt.title("Type 1 and Type 2 Errors in Hypothesis Testing")
    plt.xlabel("Test Statistic")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid()
    plt.show()

def independent_t_test(sample1, sample2, alpha=0.05):
    """
    Perform an independent two-sample T-test and interpret the results.
    :param sample1: List or array of sample data from group 1
    :param sample2: List or array of sample data from group 2
    :param alpha: Significance level (default 0.05)
    :return: T-statistic, p-value, and interpretation
    """
    t_stat, p_value = stats.ttest_ind(sample1, sample2)

    print(f"T-statistic: {t_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: There is a significant difference between the two groups.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the two groups.")

# Simulate random data for independent T-test
np.random.seed(42)  # For reproducibility
sample_group1 = np.random.normal(loc=50, scale=3, size=30)  # Mean=50, Std=3, Size=30
sample_group2 = np.random.normal(loc=52, scale=3, size=30)  # Mean=52, Std=3, Size=30
independent_t_test(sample_group1, sample_group2)

# Simulate random data for two-tailed Z-test
sample_data = np.random.normal(loc=50, scale=3, size=30)  # Mean=50, Std=3, Size=30
population_mean = 50
population_std = 3
z_test(sample_data, population_mean, population_std)

# Visualize Type 1 and Type 2 Errors
visualize_type1_type2_errors()
# Out:
# T-statistic: -3.1030
# P-value: 0.0030
# Reject the null hypothesis: There is a significant difference between the two groups.
# Sample Mean: 50.0387
# Z-score: 0.0706
# P-value: 0.9437
# Fail to reject the null hypothesis: No significant difference between the sample and population mean.

# %%
#7.Perform a paired sample T-test using Python and visualize the comparison results@
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    :param sample: List or array of sample data
    :param pop_mean: Known population mean
    :param pop_std: Known population standard deviation
    :param alpha: Significance level (default 0.05)
    :return: Z-score, p-value, and interpretation
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")

    if abs(z_score) > z_critical:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the sample and population mean.")

    # Visualization of decision region
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label="Standard Normal Distribution")

    # Shade rejection regions
    plt.fill_between(x, y, where=(x < -z_critical), color='red', alpha=0.5, label="Rejection Region")
    plt.fill_between(x, y, where=(x > z_critical), color='red', alpha=0.5)

    # Mark z-score
    plt.axvline(z_score, color='blue', linestyle='dashed', linewidth=2, label=f'Z-score: {z_score:.2f}')
    plt.axvline(-z_critical, color='black', linestyle='dotted', linewidth=2, label=f'Critical Value: ±{z_critical:.2f}')
    plt.axvline(z_critical, color='black', linestyle='dotted', linewidth=2)

    plt.title("Two-Tailed Z-Test Decision Region")
    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid()
    plt.show()

def paired_t_test(sample1, sample2, alpha=0.05):
    """
    Perform a paired sample T-test and visualize the comparison results.
    :param sample1: List or array of sample data from condition 1
    :param sample2: List or array of sample data from condition 2
    :param alpha: Significance level (default 0.05)
    :return: T-statistic, p-value, and interpretation
    """
    t_stat, p_value = stats.ttest_rel(sample1, sample2)

    print(f"T-statistic: {t_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis: There is a significant difference between the paired samples.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the paired samples.")

    # Visualization
    plt.figure(figsize=(8, 5))
    plt.scatter(range(len(sample1)), sample1, color='blue', label='Condition 1')
    plt.scatter(range(len(sample2)), sample2, color='red', label='Condition 2')
    plt.plot(range(len(sample1)), sample1, color='blue', alpha=0.5)
    plt.plot(range(len(sample2)), sample2, color='red', alpha=0.5)
    plt.title("Paired Sample Comparison")
    plt.xlabel("Sample Index")
    plt.ylabel("Value")
    plt.legend()
    plt.grid()
    plt.show()

# Simulate random data for paired T-test
np.random.seed(42)  # For reproducibility
sample_condition1 = np.random.normal(loc=50, scale=3, size=30)  # Mean=50, Std=3, Size=30
sample_condition2 = sample_condition1 + np.random.normal(loc=0, scale=1, size=30)  # Small change
paired_t_test(sample_condition1, sample_condition2)
# Out:
# T-statistic: 0.7127
# P-value: 0.4817
# Fail to reject the null hypothesis: No significant difference between the paired samples.

# %%
#8. Simulate data and perform both Z-test and T-test, then compare the results using Python@
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def t_test(sample, pop_mean, alpha=0.05):
    """
    Perform a one-sample T-test.
    """
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)
    print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def compare_tests():
    """
    Simulate data and perform both Z-test and T-test, then compare results.
    """
    np.random.seed(42)
    sample = np.random.normal(loc=50, scale=5, size=30)
    pop_mean = 50
    pop_std = 5

    print("Z-Test Results:")
    z_test(sample, pop_mean, pop_std)
    print("\nT-Test Results:")
    t_test(sample, pop_mean)

compare_tests()
# Out:
# Z-Test Results:
# Z-score: -1.0305, P-value: 0.3028
# Fail to reject the null hypothesis.
#
# T-Test Results:
# T-statistic: -1.1450, P-value: 0.2616
# Fail to reject the null hypothesis.

# %%
#9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def t_test(sample, pop_mean, alpha=0.05):
    """
    Perform a one-sample T-test.
    """
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)
    print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.
    """
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    ci_lower = sample_mean - margin_of_error
    ci_upper = sample_mean + margin_of_error

    print(f"{confidence*100:.1f}% Confidence Interval: ({ci_lower:.4f}, {ci_upper:.4f})")
    return ci_lower, ci_upper

def compare_tests():
    """
    Simulate data and perform both Z-test and T-test, then compare results.
    """
    np.random.seed(42)
    sample = np.random.normal(loc=50, scale=5, size=30)
    pop_mean = 50
    pop_std = 5

    print("Z-Test Results:")
    z_test(sample, pop_mean, pop_std)
    print("\nT-Test Results:")
    t_test(sample, pop_mean)
    print("\nConfidence Interval:")
    confidence_interval(sample)

compare_tests()
# Out:
# Z-Test Results:
# Z-score: -1.0305, P-value: 0.3028
# Fail to reject the null hypothesis.
#
# T-Test Results:
# T-statistic: -1.1450, P-value: 0.2616
# Fail to reject the null hypothesis.
#
# Confidence Interval:
# 95.0% Confidence Interval: (47.3789, 50.7396)

# %%
#10. Write a Python program to calculate the margin of error for a given confidence level using sample dataD
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def t_test(sample, pop_mean, alpha=0.05):
    """
    Perform a one-sample T-test.
    """
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)
    print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.
    """
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    ci_lower = sample_mean - margin_of_error
    ci_upper = sample_mean + margin_of_error

    print(f"{confidence*100:.1f}% Confidence Interval: ({ci_lower:.4f}, {ci_upper:.4f})")
    return ci_lower, ci_upper

def margin_of_error(sample, confidence=0.95):
    """
    Calculate the margin of error for a given confidence level using sample data.
    """
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    moe = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    print(f"Margin of Error ({confidence*100:.1f}% confidence): {moe:.4f}")
    return moe

def compare_tests():
    """
    Simulate data and perform both Z-test and T-test, then compare results.
    """
    np.random.seed(42)
    sample = np.random.normal(loc=50, scale=5, size=30)
    pop_mean = 50
    pop_std = 5

    print("Z-Test Results:")
    z_test(sample, pop_mean, pop_std)
    print("\nT-Test Results:")
    t_test(sample, pop_mean)
    print("\nConfidence Interval:")
    confidence_interval(sample)
    print("\nMargin of Error:")
    margin_of_error(sample)

compare_tests()
# Out:
# Z-Test Results:
# Z-score: -1.0305, P-value: 0.3028
# Fail to reject the null hypothesis.
#
# T-Test Results:
# T-statistic: -1.1450, P-value: 0.2616
# Fail to reject the null hypothesis.
#
# Confidence Interval:
# 95.0% Confidence Interval: (47.3789, 50.7396)
#
# Margin of Error:
# Margin of Error (95.0% confidence): 1.6803

# %%
# 11.Implement a Bayesian inference method using Bayes' Theorem in Python and explain the processD
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def t_test(sample, pop_mean, alpha=0.05):
    """
    Perform a one-sample T-test.
    """
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)
    print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.
    """
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    ci_lower = sample_mean - margin_of_error
    ci_upper = sample_mean + margin_of_error

    print(f"{confidence*100:.1f}% Confidence Interval: ({ci_lower:.4f}, {ci_upper:.4f})")
    return ci_lower, ci_upper

def margin_of_error(sample, confidence=0.95):
    """
    Calculate the margin of error for a given confidence level using sample data.
    """
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    moe = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    print(f"Margin of Error ({confidence*100:.1f}% confidence): {moe:.4f}")
    return moe

def bayes_theorem(prior, likelihood, evidence):
    """
    Implement Bayesian inference using Bayes' Theorem.
    """
    posterior = (likelihood * prior) / evidence
    print(f"Posterior Probability: {posterior:.4f}")
    return posterior

def compare_tests():
    """
    Simulate data and perform both Z-test and T-test, then compare results.
    """
    np.random.seed(42)
    sample = np.random.normal(loc=50, scale=5, size=30)
    pop_mean = 50
    pop_std = 5

    print("Z-Test Results:")
    z_test(sample, pop_mean, pop_std)
    print("\nT-Test Results:")
    t_test(sample, pop_mean)
    print("\nConfidence Interval:")
    confidence_interval(sample)
    print("\nMargin of Error:")
    margin_of_error(sample)
    print("\nBayes' Theorem Example:")
    bayes_theorem(prior=0.5, likelihood=0.7, evidence=0.6)

compare_tests()
# Out:
# Z-Test Results:
# Z-score: -1.0305, P-value: 0.3028
# Fail to reject the null hypothesis.
#
# T-Test Results:
# T-statistic: -1.1450, P-value: 0.2616
# Fail to reject the null hypothesis.
#
# Confidence Interval:
# 95.0% Confidence Interval: (47.3789, 50.7396)
#
# Margin of Error:
# Margin of Error (95.0% confidence): 1.6803
#
# Bayes' Theorem Example:
# Posterior Probability: 0.5833

# %%
#12.Perform a Chi-square test for independence between two categorical variables in PythonD
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import chi2_contingency

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def t_test(sample, pop_mean, alpha=0.05):
    """
    Perform a one-sample T-test.
    """
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)
    print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.
    """
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    ci_lower = sample_mean - margin_of_error
    ci_upper = sample_mean + margin_of_error

    print(f"{confidence*100:.1f}% Confidence Interval: ({ci_lower:.4f}, {ci_upper:.4f})")
    return ci_lower, ci_upper

def margin_of_error(sample, confidence=0.95):
    """
    Calculate the margin of error for a given confidence level using sample data.
    """
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    moe = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    print(f"Margin of Error ({confidence*100:.1f}% confidence): {moe:.4f}")
    return moe

def bayes_theorem(prior, likelihood, evidence):
    """
    Implement Bayesian inference using Bayes' Theorem.
    """
    posterior = (likelihood * prior) / evidence
    print(f"Posterior Probability: {posterior:.4f}")
    return posterior

def chi_square_test(data):
    """
    Perform a Chi-square test for independence between two categorical variables.
    """
    chi2, p, dof, expected = chi2_contingency(data)
    print(f"Chi-square Statistic: {chi2:.4f}, P-value: {p:.4f}")
    if p < 0.05:
        print("Reject the null hypothesis: Variables are dependent.")
    else:
        print("Fail to reject the null hypothesis: Variables are independent.")

def compare_tests():
    """
    Simulate data and perform both Z-test and T-test, then compare results.
    """
    np.random.seed(42)
    sample = np.random.normal(loc=50, scale=5, size=30)
    pop_mean = 50
    pop_std = 5

    print("Z-Test Results:")
    z_test(sample, pop_mean, pop_std)
    print("\nT-Test Results:")
    t_test(sample, pop_mean)
    print("\nConfidence Interval:")
    confidence_interval(sample)
    print("\nMargin of Error:")
    margin_of_error(sample)
    print("\nBayes' Theorem Example:")
    bayes_theorem(prior=0.5, likelihood=0.7, evidence=0.6)

    # Example data for Chi-square test
    observed_data = np.array([[30, 10], [15, 25]])
    print("\nChi-square Test for Independence:")
    chi_square_test(observed_data)

compare_tests()
# Out:
# Z-Test Results:
# Z-score: -1.0305, P-value: 0.3028
# Fail to reject the null hypothesis.
#
# T-Test Results:
# T-statistic: -1.1450, P-value: 0.2616
# Fail to reject the null hypothesis.
#
# Confidence Interval:
# 95.0% Confidence Interval: (47.3789, 50.7396)
#
# Margin of Error:
# Margin of Error (95.0% confidence): 1.6803
#
# Bayes' Theorem Example:
# Posterior Probability: 0.5833
#
# Chi-square Test for Independence:
# Chi-square Statistic: 9.9556, P-value: 0.0016
# Reject the null hypothesis: Variables are dependent.

# %%
#13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data?
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import chi2_contingency

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def t_test(sample, pop_mean, alpha=0.05):
    """
    Perform a one-sample T-test.
    """
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)
    print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.
    """
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    ci_lower = sample_mean - margin_of_error
    ci_upper = sample_mean + margin_of_error

    print(f"{confidence*100:.1f}% Confidence Interval: ({ci_lower:.4f}, {ci_upper:.4f})")
    return ci_lower, ci_upper

def margin_of_error(sample, confidence=0.95):
    """
    Calculate the margin of error for a given confidence level using sample data.
    """
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    moe = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    print(f"Margin of Error ({confidence*100:.1f}% confidence): {moe:.4f}")
    return moe

def bayes_theorem(prior, likelihood, evidence):
    """
    Implement Bayesian inference using Bayes' Theorem.
    """
    posterior = (likelihood * prior) / evidence
    print(f"Posterior Probability: {posterior:.4f}")
    return posterior

def chi_square_test(data):
    """
    Perform a Chi-square test for independence between two categorical variables.
    """
    chi2, p, dof, expected = chi2_contingency(data)
    print(f"Chi-square Statistic: {chi2:.4f}, P-value: {p:.4f}")
    print("Expected Frequencies:")
    print(expected)
    if p < 0.05:
        print("Reject the null hypothesis: Variables are dependent.")
    else:
        print("Fail to reject the null hypothesis: Variables are independent.")

def expected_frequencies(data):
    """
    Calculate expected frequencies for a Chi-square test based on observed data.
    """
    _, _, _, expected = chi2_contingency(data)
    print("Expected Frequencies:")
    print(expected)
    return expected

def compare_tests():
    """
    Simulate data and perform both Z-test and T-test, then compare results.
    """
    np.random.seed(42)
    sample = np.random.normal(loc=50, scale=5, size=30)
    pop_mean = 50
    pop_std = 5

    print("Z-Test Results:")
    z_test(sample, pop_mean, pop_std)
    print("\nT-Test Results:")
    t_test(sample, pop_mean)
    print("\nConfidence Interval:")
    confidence_interval(sample)
    print("\nMargin of Error:")
    margin_of_error(sample)
    print("\nBayes' Theorem Example:")
    bayes_theorem(prior=0.5, likelihood=0.7, evidence=0.6)

    # Example data for Chi-square test
    observed_data = np.array([[30, 10], [15, 25]])
    print("\nChi-square Test for Independence:")
    chi_square_test(observed_data)
    print("\nExpected Frequencies for Chi-square Test:")
    expected_frequencies(observed_data)

compare_tests()
# Out:
# Z-Test Results:
# Z-score: -1.0305, P-value: 0.3028
# Fail to reject the null hypothesis.
#
# T-Test Results:
# T-statistic: -1.1450, P-value: 0.2616
# Fail to reject the null hypothesis.
#
# Confidence Interval:
# 95.0% Confidence Interval: (47.3789, 50.7396)
#
# Margin of Error:
# Margin of Error (95.0% confidence): 1.6803
#
# Bayes' Theorem Example:
# Posterior Probability: 0.5833
#
# Chi-square Test for Independence:
# Chi-square Statistic: 9.9556, P-value: 0.0016
# Expected Frequencies:
# [[22.5 17.5]
#  [22.5 17.5]]
# Reject the null hypothesis: Variables are dependent.
#
# Expected Frequencies for Chi-square Test:
# Expected Frequencies:
# [[22.5 17.5]
#  [22.5 17.5]]

# %%
#14.  Perform a goodness-of-fit test using Python to compare the observed data to an expected distributionD
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import chi2_contingency, chisquare

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def t_test(sample, pop_mean, alpha=0.05):
    """
    Perform a one-sample T-test.
    """
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)
    print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.
    """
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    ci_lower = sample_mean - margin_of_error
    ci_upper = sample_mean + margin_of_error

    print(f"{confidence*100:.1f}% Confidence Interval: ({ci_lower:.4f}, {ci_upper:.4f})")
    return ci_lower, ci_upper

def goodness_of_fit_test(observed, expected):
    """
    Perform a Chi-square goodness-of-fit test.
    """
    chi2_stat, p_value = chisquare(observed, f_exp=expected)
    print(f"Chi-square Statistic: {chi2_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: Observed distribution differs from expected.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between observed and expected.")

def compare_tests():
    """
    Simulate data and perform both Z-test and T-test, then compare results.
    """
    np.random.seed(42)
    sample = np.random.normal(loc=50, scale=5, size=30)
    pop_mean = 50
    pop_std = 5

    print("Z-Test Results:")
    z_test(sample, pop_mean, pop_std)
    print("\nT-Test Results:")
    t_test(sample, pop_mean)
    print("\nConfidence Interval:")
    confidence_interval(sample)

    # Example data for Goodness-of-Fit Test
    observed_values = np.array([50, 30, 20])
    expected_values = np.array([40, 40, 20])
    print("\nChi-square Goodness-of-Fit Test:")
    goodness_of_fit_test(observed_values, expected_values)

compare_tests()
# Out:
# Z-Test Results:
# Z-score: -1.0305, P-value: 0.3028
# Fail to reject the null hypothesis.
#
# T-Test Results:
# T-statistic: -1.1450, P-value: 0.2616
# Fail to reject the null hypothesis.
#
# Confidence Interval:
# 95.0% Confidence Interval: (47.3789, 50.7396)
#
# Chi-square Goodness-of-Fit Test:
# Chi-square Statistic: 5.0000, P-value: 0.0821
# Fail to reject the null hypothesis: No significant difference between observed and expected.

# %%
#15.Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics?
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import chi2_contingency, chisquare, chi2

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def t_test(sample, pop_mean, alpha=0.05):
    """
    Perform a one-sample T-test.
    """
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)
    print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.
    """
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    ci_lower = sample_mean - margin_of_error
    ci_upper = sample_mean + margin_of_error

    print(f"{confidence*100:.1f}% Confidence Interval: ({ci_lower:.4f}, {ci_upper:.4f})")
    return ci_lower, ci_upper

def goodness_of_fit_test(observed, expected):
    """
    Perform a Chi-square goodness-of-fit test.
    """
    chi2_stat, p_value = chisquare(observed, f_exp=expected)
    print(f"Chi-square Statistic: {chi2_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: Observed distribution differs from expected.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between observed and expected.")

def simulate_chi_square(df, size=10000):
    """
    Simulate and visualize the Chi-square distribution.
    """
    data = np.random.chisquare(df, size)
    plt.figure(figsize=(8, 5))
    plt.hist(data, bins=50, density=True, alpha=0.6, color='b', label=f'Chi-square (df={df})')

    x = np.linspace(0, max(data), 1000)
    plt.plot(x, chi2.pdf(x, df), 'r-', label='Theoretical PDF')

    plt.title(f'Chi-square Distribution (df={df})')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.legend()
    plt.show()

def compare_tests():
    """
    Simulate data and perform both Z-test and T-test, then compare results.
    """
    np.random.seed(42)
    sample = np.random.normal(loc=50, scale=5, size=30)
    pop_mean = 50
    pop_std = 5

    print("Z-Test Results:")
    z_test(sample, pop_mean, pop_std)
    print("\nT-Test Results:")
    t_test(sample, pop_mean)
    print("\nConfidence Interval:")
    confidence_interval(sample)

    # Example data for Goodness-of-Fit Test
    observed_values = np.array([50, 30, 20])
    expected_values = np.array([40, 40, 20])
    print("\nChi-square Goodness-of-Fit Test:")
    goodness_of_fit_test(observed_values, expected_values)

    # Simulate and visualize Chi-square distribution
    print("\nSimulating and Visualizing Chi-square Distribution:")
    simulate_chi_square(df=5)

compare_tests()
# Out:
# Z-Test Results:
# Z-score: -1.0305, P-value: 0.3028
# Fail to reject the null hypothesis.
#
# T-Test Results:
# T-statistic: -1.1450, P-value: 0.2616
# Fail to reject the null hypothesis.
#
# Confidence Interval:
# 95.0% Confidence Interval: (47.3789, 50.7396)
#
# Chi-square Goodness-of-Fit Test:
# Chi-square Statistic: 5.0000, P-value: 0.0821
# Fail to reject the null hypothesis: No significant difference between observed and expected.
#
# Simulating and Visualizing Chi-square Distribution:

# %%
#16. Implement an F-test using Python to compare the variances of two random samplesD
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def t_test(sample, pop_mean, alpha=0.05):
    """
    Perform a one-sample T-test.
    """
    t_stat, p_value = stats.ttest_1samp(sample, pop_mean)
    print(f"T-statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.
    """
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation
    sample_size = len(sample)
    standard_error = sample_std / np.sqrt(sample_size)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size-1) * standard_error
    ci_lower = sample_mean - margin_of_error
    ci_upper = sample_mean + margin_of_error

    print(f"{confidence*100:.1f}% Confidence Interval: ({ci_lower:.4f}, {ci_upper:.4f})")
    return ci_lower, ci_upper

def goodness_of_fit_test(observed, expected):
    """
    Perform a Chi-square goodness-of-fit test.
    """
    chi2_stat, p_value = chisquare(observed, f_exp=expected)
    print(f"Chi-square Statistic: {chi2_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: Observed distribution differs from expected.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between observed and expected.")

def simulate_chi_square(df, size=10000):
    """
    Simulate and visualize the Chi-square distribution.
    """
    data = np.random.chisquare(df, size)
    plt.figure(figsize=(8, 5))
    plt.hist(data, bins=50, density=True, alpha=0.6, color='b', label=f'Chi-square (df={df})')

    x = np.linspace(0, max(data), 1000)
    plt.plot(x, chi2.pdf(x, df), 'r-', label='Theoretical PDF')

    plt.title(f'Chi-square Distribution (df={df})')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.legend()
    plt.show()

def f_test(sample1, sample2, alpha=0.05):
    """
    Perform an F-test to compare the variances of two independent samples.
    """
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)
    f_stat = var1 / var2 if var1 > var2 else var2 / var1
    df1 = len(sample1) - 1
    df2 = len(sample2) - 1
    p_value = 1 - stats.f.cdf(f_stat, df1, df2)

    print(f"F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < alpha:
        print("Reject the null hypothesis: The variances are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference in variances.")

def compare_tests():
    """
    Simulate data and perform various statistical tests.
    """
    np.random.seed(42)
    sample = np.random.normal(loc=50, scale=5, size=30)
    pop_mean = 50
    pop_std = 5

    print("Z-Test Results:")
    z_test(sample, pop_mean, pop_std)
    print("\nT-Test Results:")
    t_test(sample, pop_mean)
    print("\nConfidence Interval:")
    confidence_interval(sample)

    # Example data for Goodness-of-Fit Test
    observed_values = np.array([50, 30, 20])
    expected_values = np.array([40, 40, 20])
    print("\nChi-square Goodness-of-Fit Test:")
    goodness_of_fit_test(observed_values, expected_values)

    # Simulate and visualize Chi-square distribution
    print("\nSimulating and Visualizing Chi-square Distribution:")
    simulate_chi_square(df=5)

    # Generate two independent samples for F-test
    sample1 = np.random.normal(loc=50, scale=5, size=30)
    sample2 = np.random.normal(loc=50, scale=10, size=30)
    print("\nF-Test for Variance Comparison:")
    f_test(sample1, sample2)

compare_tests()
# Out:
# Z-Test Results:
# Z-score: -1.0305, P-value: 0.3028
# Fail to reject the null hypothesis.
#
# T-Test Results:
# T-statistic: -1.1450, P-value: 0.2616
# Fail to reject the null hypothesis.
#
# Confidence Interval:
# 95.0% Confidence Interval: (47.3789, 50.7396)
#
# Chi-square Goodness-of-Fit Test:
# Chi-square Statistic: 5.0000, P-value: 0.0821
# Fail to reject the null hypothesis: No significant difference between observed and expected.
#
# Simulating and Visualizing Chi-square Distribution:
# F-Test for Variance Comparison:
# F-statistic: 3.2694, P-value: 0.0010
# Reject the null hypothesis: The variances are significantly different.

# %%
#17.  Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results?
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def anova_test(*groups):
    """
    Perform a one-way ANOVA test to compare means between multiple groups.
    """
    f_stat, p_value = f_oneway(*groups)
    print(f"ANOVA F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference among group means.")

def compare_tests():
    """
    Simulate data and perform various statistical tests.
    """
    np.random.seed(42)

    # Simulate data for ANOVA test
    group1 = np.random.normal(loc=50, scale=5, size=30)
    group2 = np.random.normal(loc=52, scale=5, size=30)
    group3 = np.random.normal(loc=48, scale=5, size=30)

    print("\nANOVA Test Results:")
    anova_test(group1, group2, group3)

compare_tests()
# Out:
# ANOVA Test Results:
# ANOVA F-statistic: 3.9524, P-value: 0.0228
# Reject the null hypothesis: At least one group mean is significantly different.

# %%
#18.Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results?
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def anova_test(*groups):
    """
    Perform a one-way ANOVA test to compare means between multiple groups and visualize the results.
    """
    f_stat, p_value = f_oneway(*groups)
    print(f"ANOVA F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference among group means.")

    # Boxplot visualization
    plt.figure(figsize=(8, 5))
    plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
    plt.title("ANOVA Test: Comparison of Group Means")
    plt.ylabel("Values")
    plt.show()

def compare_tests():
    """
    Simulate data and perform various statistical tests.
    """
    np.random.seed(42)

    # Simulate data for ANOVA test
    group1 = np.random.normal(loc=50, scale=5, size=30)
    group2 = np.random.normal(loc=52, scale=5, size=30)
    group3 = np.random.normal(loc=48, scale=5, size=30)

    print("\nANOVA Test Results:")
    anova_test(group1, group2, group3)

compare_tests()
# Out:
# ANOVA Test Results:
# ANOVA F-statistic: 3.9524, P-value: 0.0228
# Reject the null hypothesis: At least one group mean is significantly different.
# <ipython-input-19-39b1dcd2e242>:45: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])

# %%
#19.Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway, levene, shapiro

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def check_anova_assumptions(*groups):
    """
    Check assumptions for ANOVA: Normality, Independence, and Equal Variance.
    """
    print("Checking ANOVA assumptions:")

    # Normality test (Shapiro-Wilk test)
    for i, group in enumerate(groups):
        stat, p = shapiro(group)
        print(f"Group {i+1} Normality Test: W={stat:.4f}, P-value={p:.4f}")
        if p < 0.05:
            print(f"Group {i+1} is NOT normally distributed.")
        else:
            print(f"Group {i+1} appears to be normally distributed.")

    # Equal Variance Test (Levene's test)
    stat, p = levene(*groups)
    print(f"Levene's Test for Equal Variance: W={stat:.4f}, P-value={p:.4f}")
    if p < 0.05:
        print("Groups do NOT have equal variances (heteroscedasticity detected).")
    else:
        print("Groups have approximately equal variances.")

def anova_test(*groups):
    """
    Perform a one-way ANOVA test to compare means between multiple groups and visualize the results.
    """
    check_anova_assumptions(*groups)

    f_stat, p_value = f_oneway(*groups)
    print(f"ANOVA F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference among group means.")

    # Boxplot visualization
    plt.figure(figsize=(8, 5))
    plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
    plt.title("ANOVA Test: Comparison of Group Means")
    plt.ylabel("Values")
    plt.show()

def compare_tests():
    """
    Simulate data and perform various statistical tests.
    """
    np.random.seed(42)

    # Simulate data for ANOVA test
    group1 = np.random.normal(loc=50, scale=5, size=30)
    group2 = np.random.normal(loc=52, scale=5, size=30)
    group3 = np.random.normal(loc=48, scale=5, size=30)

    print("\nANOVA Test Results:")
    anova_test(group1, group2, group3)

compare_tests()
# Out:
# ANOVA Test Results:
# Checking ANOVA assumptions:
# Group 1 Normality Test: W=0.9751, P-value=0.6868
# Group 1 appears to be normally distributed.
# Group 2 Normality Test: W=0.9837, P-value=0.9130
# Group 2 appears to be normally distributed.
# Group 3 Normality Test: W=0.9628, P-value=0.3654
# Group 3 appears to be normally distributed.
# Levene's Test for Equal Variance: W=0.1480, P-value=0.8627
# Groups have approximately equal variances.
# ANOVA F-statistic: 3.9524, P-value: 0.0228
# Reject the null hypothesis: At least one group mean is significantly different.
# <ipython-input-20-1eb35f6ae300>:70: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])

# %%
#20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results?
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway, levene, shapiro

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def check_anova_assumptions(*groups):
    """
    Check assumptions for ANOVA: Normality, Independence, and Equal Variance.
    """
    print("Checking ANOVA assumptions:")

    # Normality test (Shapiro-Wilk test)
    for i, group in enumerate(groups):
        stat, p = shapiro(group)
        print(f"Group {i+1} Normality Test: W={stat:.4f}, P-value={p:.4f}")
        if p < 0.05:
            print(f"Group {i+1} is NOT normally distributed.")
        else:
            print(f"Group {i+1} appears to be normally distributed.")

    # Equal Variance Test (Levene's test)
    stat, p = levene(*groups)
    print(f"Levene's Test for Equal Variance: W={stat:.4f}, P-value={p:.4f}")
    if p < 0.05:
        print("Groups do NOT have equal variances (heteroscedasticity detected).")
    else:
        print("Groups have approximately equal variances.")

def anova_test(*groups):
    """
    Perform a one-way ANOVA test to compare means between multiple groups and visualize the results.
    """
    check_anova_assumptions(*groups)

    f_stat, p_value = f_oneway(*groups)
    print(f"ANOVA F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference among group means.")

    # Boxplot visualization
    plt.figure(figsize=(8, 5))
    plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
    plt.title("ANOVA Test: Comparison of Group Means")
    plt.ylabel("Values")
    plt.show()

def two_way_anova(data, factor1, factor2, response):
    """
    Perform a two-way ANOVA test and visualize the results.
    """
    formula = f'{response} ~ C({factor1}) + C({factor2}) + C({factor1}):C({factor2})'
    model = smf.ols(formula, data=data).fit()
    anova_results = sm.stats.anova_lm(model, typ=2)
    print("Two-Way ANOVA Results:")
    print(anova_results)

    # Boxplot visualization
    plt.figure(figsize=(10, 6))
    data.boxplot(column=response, by=[factor1, factor2], grid=False)
    plt.title("Two-Way ANOVA: Interaction Between Factors")
    plt.suptitle("")
    plt.xlabel("Factors")
    plt.ylabel(response)
    plt.show()

def compare_tests():
    """
    Simulate data and perform various statistical tests.
    """
    np.random.seed(42)

    # Simulate data for ANOVA test
    group1 = np.random.normal(loc=50, scale=5, size=30)
    group2 = np.random.normal(loc=52, scale=5, size=30)
    group3 = np.random.normal(loc=48, scale=5, size=30)

    print("\nANOVA Test Results:")
    anova_test(group1, group2, group3)

    # Simulate data for Two-Way ANOVA
    data = pd.DataFrame({
        'Factor1': np.repeat(['A', 'B'], 30),
        'Factor2': np.tile(['X', 'Y'], 30),
        'Response': np.concatenate([np.random.normal(50, 5, 30), np.random.normal(55, 5, 30)])
    })

    print("\nTwo-Way ANOVA Test Results:")
    two_way_anova(data, 'Factor1', 'Factor2', 'Response')

compare_tests()
# Out:
# ANOVA Test Results:
# Checking ANOVA assumptions:
# Group 1 Normality Test: W=0.9751, P-value=0.6868
# Group 1 appears to be normally distributed.
# Group 2 Normality Test: W=0.9837, P-value=0.9130
# Group 2 appears to be normally distributed.
# Group 3 Normality Test: W=0.9628, P-value=0.3654
# Group 3 appears to be normally distributed.
# Levene's Test for Equal Variance: W=0.1480, P-value=0.8627
# Groups have approximately equal variances.
# ANOVA F-statistic: 3.9524, P-value: 0.0228
# Reject the null hypothesis: At least one group mean is significantly different.
# <ipython-input-21-ed782e4a6d69>:72: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
# Two-Way ANOVA Test Results:
# Two-Way ANOVA Results:
#                             sum_sq    df          F    PR(>F)
# ...

# %%
#21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing?
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway, levene, shapiro

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a one-sample two-tailed Z-test and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = pop_std / np.sqrt(sample_size)

    # Calculate Z-score
    z_score = (sample_mean - pop_mean) / standard_error

    # Calculate p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Determine critical values
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Interpret the results
    print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis.")
    else:
        print("Fail to reject the null hypothesis.")

def check_anova_assumptions(*groups):
    """
    Check assumptions for ANOVA: Normality, Independence, and Equal Variance.
    """
    print("Checking ANOVA assumptions:")

    # Normality test (Shapiro-Wilk test)
    for i, group in enumerate(groups):
        stat, p = shapiro(group)
        print(f"Group {i+1} Normality Test: W={stat:.4f}, P-value={p:.4f}")
        if p < 0.05:
            print(f"Group {i+1} is NOT normally distributed.")
        else:
            print(f"Group {i+1} appears to be normally distributed.")

    # Equal Variance Test (Levene's test)
    stat, p = levene(*groups)
    print(f"Levene's Test for Equal Variance: W={stat:.4f}, P-value={p:.4f}")
    if p < 0.05:
        print("Groups do NOT have equal variances (heteroscedasticity detected).")
    else:
        print("Groups have approximately equal variances.")

def anova_test(*groups):
    """
    Perform a one-way ANOVA test to compare means between multiple groups and visualize the results.
    """
    check_anova_assumptions(*groups)

    f_stat, p_value = f_oneway(*groups)
    print(f"ANOVA F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference among group means.")

    # Boxplot visualization
    plt.figure(figsize=(8, 5))
    plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
    plt.title("ANOVA Test: Comparison of Group Means")
    plt.ylabel("Values")
    plt.show()

def two_way_anova(data, factor1, factor2, response):
    """
    Perform a two-way ANOVA test and visualize the results.
    """
    formula = f'{response} ~ C({factor1}) + C({factor2}) + C({factor1}):C({factor2})'
    model = smf.ols(formula, data=data).fit()
    anova_results = sm.stats.anova_lm(model, typ=2)
    print("Two-Way ANOVA Results:")
    print(anova_results)

    # Boxplot visualization
    plt.figure(figsize=(10, 6))
    data.boxplot(column=response, by=[factor1, factor2], grid=False)
    plt.title("Two-Way ANOVA: Interaction Between Factors")
    plt.suptitle("")
    plt.xlabel("Factors")
    plt.ylabel(response)
    plt.show()

def visualize_f_distribution(df1, df2):
    """
    Visualize the F-distribution for given degrees of freedom.
    """
    x = np.linspace(0, 5, 1000)
    y = stats.f.pdf(x, df1, df2)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label=f'F-distribution (df1={df1}, df2={df2})')
    plt.fill_between(x, y, alpha=0.3)
    plt.title("F-Distribution Visualization")
    plt.xlabel("F-value")
    plt.ylabel("Density")
    plt.legend()
    plt.grid()
    plt.show()

    print("The F-distribution is used in ANOVA and variance comparison tests.")

def compare_tests():
    """
    Simulate data and perform various statistical tests.
    """
    np.random.seed(42)

    # Simulate data for ANOVA test
    group1 = np.random.normal(loc=50, scale=5, size=30)
    group2 = np.random.normal(loc=52, scale=5, size=30)
    group3 = np.random.normal(loc=48, scale=5, size=30)

    print("\nANOVA Test Results:")
    anova_test(group1, group2, group3)

    # Simulate data for Two-Way ANOVA
    data = pd.DataFrame({
        'Factor1': np.repeat(['A', 'B'], 30),
        'Factor2': np.tile(['X', 'Y'], 30),
        'Response': np.concatenate([np.random.normal(50, 5, 30), np.random.normal(55, 5, 30)])
    })

    print("\nTwo-Way ANOVA Test Results:")
    two_way_anova(data, 'Factor1', 'Factor2', 'Response')

    # Visualize F-distribution
    visualize_f_distribution(5, 10)

compare_tests()
# Out:
# ANOVA Test Results:
# Checking ANOVA assumptions:
# Group 1 Normality Test: W=0.9751, P-value=0.6868
# Group 1 appears to be normally distributed.
# Group 2 Normality Test: W=0.9837, P-value=0.9130
# Group 2 appears to be normally distributed.
# Group 3 Normality Test: W=0.9628, P-value=0.3654
# Group 3 appears to be normally distributed.
# Levene's Test for Equal Variance: W=0.1480, P-value=0.8627
# Groups have approximately equal variances.
# ANOVA F-statistic: 3.9524, P-value: 0.0228
# Reject the null hypothesis: At least one group mean is significantly different.
# <ipython-input-22-c9e63759bc0d>:72: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
# Two-Way ANOVA Test Results:
# Two-Way ANOVA Results:
#                             sum_sq    df          F    PR(>F)
# ...

# %%
#22.  Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway, levene, shapiro

def check_anova_assumptions(*groups):
    """
    Check assumptions for ANOVA: Normality, Independence, and Equal Variance.
    """
    print("Checking ANOVA assumptions:")

    # Normality test (Shapiro-Wilk test)
    for i, group in enumerate(groups):
        stat, p = shapiro(group)
        print(f"Group {i+1} Normality Test: W={stat:.4f}, P-value={p:.4f}")
        if p < 0.05:
            print(f"Group {i+1} is NOT normally distributed.")
        else:
            print(f"Group {i+1} appears to be normally distributed.")

    # Equal Variance Test (Levene's test)
    stat, p = levene(*groups)
    print(f"Levene's Test for Equal Variance: W={stat:.4f}, P-value={p:.4f}")
    if p < 0.05:
        print("Groups do NOT have equal variances (heteroscedasticity detected).")
    else:
        print("Groups have approximately equal variances.")

def one_way_anova(*groups):
    """
    Perform a one-way ANOVA test to compare means between multiple groups and visualize the results.
    """
    check_anova_assumptions(*groups)

    f_stat, p_value = f_oneway(*groups)
    print(f"ANOVA F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference among group means.")

    # Boxplot visualization
    plt.figure(figsize=(8, 5))
    plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
    plt.title("One-Way ANOVA Test: Comparison of Group Means")
    plt.ylabel("Values")
    plt.show()

def visualize_f_distribution(df1, df2):
    """
    Visualize the F-distribution for given degrees of freedom.
    """
    x = np.linspace(0, 5, 1000)
    y = stats.f.pdf(x, df1, df2)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label=f'F-distribution (df1={df1}, df2={df2})')
    plt.fill_between(x, y, alpha=0.3)
    plt.title("F-Distribution Visualization")
    plt.xlabel("F-value")
    plt.ylabel("Density")
    plt.legend()
    plt.grid()
    plt.show()

    print("The F-distribution is used in ANOVA and variance comparison tests.")

def compare_tests():
    """
    Simulate data and perform a one-way ANOVA test.
    """
    np.random.seed(42)

    # Simulate data for ANOVA test
    group1 = np.random.normal(loc=50, scale=5, size=30)
    group2 = np.random.normal(loc=52, scale=5, size=30)
    group3 = np.random.normal(loc=48, scale=5, size=30)

    print("\nOne-Way ANOVA Test Results:")
    one_way_anova(group1, group2, group3)

compare_tests()
# Out:
# One-Way ANOVA Test Results:
# Checking ANOVA assumptions:
# Group 1 Normality Test: W=0.9751, P-value=0.6868
# Group 1 appears to be normally distributed.
# Group 2 Normality Test: W=0.9837, P-value=0.9130
# Group 2 appears to be normally distributed.
# Group 3 Normality Test: W=0.9628, P-value=0.3654
# Group 3 appears to be normally distributed.
# Levene's Test for Equal Variance: W=0.1480, P-value=0.8627
# Groups have approximately equal variances.
# ANOVA F-statistic: 3.9524, P-value: 0.0228
# Reject the null hypothesis: At least one group mean is significantly different.
# <ipython-input-23-be69d3af8fc5>:48: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])

# %%
#23.Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means?
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway, levene, shapiro, ttest_ind

def check_anova_assumptions(*groups):
    """
    Check assumptions for ANOVA: Normality, Independence, and Equal Variance.
    """
    print("Checking ANOVA assumptions:")

    # Normality test (Shapiro-Wilk test)
    for i, group in enumerate(groups):
        stat, p = shapiro(group)
        print(f"Group {i+1} Normality Test: W={stat:.4f}, P-value={p:.4f}")
        if p < 0.05:
            print(f"Group {i+1} is NOT normally distributed.")
        else:
            print(f"Group {i+1} appears to be normally distributed.")

    # Equal Variance Test (Levene's test)
    stat, p = levene(*groups)
    print(f"Levene's Test for Equal Variance: W={stat:.4f}, P-value={p:.4f}")
    if p < 0.05:
        print("Groups do NOT have equal variances (heteroscedasticity detected).")
    else:
        print("Groups have approximately equal variances.")

def one_way_anova(*groups):
    """
    Perform a one-way ANOVA test to compare means between multiple groups and visualize the results.
    """
    check_anova_assumptions(*groups)

    f_stat, p_value = f_oneway(*groups)
    print(f"ANOVA F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference among group means.")

    # Boxplot visualization
    plt.figure(figsize=(8, 5))
    plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
    plt.title("One-Way ANOVA Test: Comparison of Group Means")
    plt.ylabel("Values")
    plt.show()

def perform_t_test(sample1, sample2):
    """
    Perform an independent t-test to compare means of two samples.
    """
    t_stat, p_value = ttest_ind(sample1, sample2)
    print(f"T-Test Statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: The two sample means are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between sample means.")

def simulate_and_test():
    """
    Simulate data from a normal distribution and perform hypothesis testing.
    """
    np.random.seed(42)

    # Simulate random normal data
    sample1 = np.random.normal(loc=50, scale=5, size=30)
    sample2 = np.random.normal(loc=52, scale=5, size=30)

    print("\nIndependent T-Test Results:")
    perform_t_test(sample1, sample2)

    print("\nOne-Way ANOVA Test Results:")
    one_way_anova(sample1, sample2)

simulate_and_test()
# Out:
# Independent T-Test Results:
# T-Test Statistic: -1.9752, P-value: 0.0530
# Fail to reject the null hypothesis: No significant difference between sample means.
#
# One-Way ANOVA Test Results:
# Checking ANOVA assumptions:
# Group 1 Normality Test: W=0.9751, P-value=0.6868
# Group 1 appears to be normally distributed.
# Group 2 Normality Test: W=0.9837, P-value=0.9130
# Group 2 appears to be normally distributed.
# Levene's Test for Equal Variance: W=0.2452, P-value=0.6223
# Groups have approximately equal variances.
# ANOVA F-statistic: 3.9012, P-value: 0.0530
# Fail to reject the null hypothesis: No significant difference among group means.
# <ipython-input-24-7b39167aaa4d>:48: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])

# %%
#24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the resultsD
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway, levene, shapiro, ttest_ind

def check_anova_assumptions(*groups):
    """
    Check assumptions for ANOVA: Normality, Independence, and Equal Variance.
    """
    print("Checking ANOVA assumptions:")

    # Normality test (Shapiro-Wilk test)
    for i, group in enumerate(groups):
        stat, p = shapiro(group)
        print(f"Group {i+1} Normality Test: W={stat:.4f}, P-value={p:.4f}")
        if p < 0.05:
            print(f"Group {i+1} is NOT normally distributed.")
        else:
            print(f"Group {i+1} appears to be normally distributed.")

    # Equal Variance Test (Levene's test)
    stat, p = levene(*groups)
    print(f"Levene's Test for Equal Variance: W={stat:.4f}, P-value={p:.4f}")
    if p < 0.05:
        print("Groups do NOT have equal variances (heteroscedasticity detected).")
    else:
        print("Groups have approximately equal variances.")

def one_way_anova(*groups):
    """
    Perform a one-way ANOVA test to compare means between multiple groups and visualize the results.
    """
    check_anova_assumptions(*groups)

    f_stat, p_value = f_oneway(*groups)
    print(f"ANOVA F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference among group means.")

    # Boxplot visualization
    plt.figure(figsize=(8, 5))
    plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
    plt.title("One-Way ANOVA Test: Comparison of Group Means")
    plt.ylabel("Values")
    plt.show()

def perform_t_test(sample1, sample2):
    """
    Perform an independent t-test to compare means of two samples.
    """
    t_stat, p_value = ttest_ind(sample1, sample2)
    print(f"T-Test Statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: The two sample means are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between sample means.")

def perform_variance_test(sample, pop_variance):
    """
    Perform a hypothesis test for population variance using the Chi-square distribution.
    """
    n = len(sample)
    sample_variance = np.var(sample, ddof=1)  # Sample variance
    chi_square_stat = (n - 1) * sample_variance / pop_variance
    p_value = 1 - chi2.cdf(chi_square_stat, df=n-1)  # Upper tail test

    print(f"Chi-square Test Statistic: {chi_square_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: The population variance is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference in population variance.")

def simulate_and_test():
    """
    Simulate data from a normal distribution and perform hypothesis testing.
    """
    np.random.seed(42)

    # Simulate random normal data
    sample1 = np.random.normal(loc=50, scale=5, size=30)
    sample2 = np.random.normal(loc=52, scale=5, size=30)

    print("\nIndependent T-Test Results:")
    perform_t_test(sample1, sample2)

    print("\nOne-Way ANOVA Test Results:")
    one_way_anova(sample1, sample2)

    print("\nChi-Square Test for Population Variance:")
    perform_variance_test(sample1, pop_variance=25)  # Assuming population variance = 25

simulate_and_test()
# Out:
# Independent T-Test Results:
# T-Test Statistic: -1.9752, P-value: 0.0530
# Fail to reject the null hypothesis: No significant difference between sample means.
#
# One-Way ANOVA Test Results:
# Checking ANOVA assumptions:
# Group 1 Normality Test: W=0.9751, P-value=0.6868
# Group 1 appears to be normally distributed.
# Group 2 Normality Test: W=0.9837, P-value=0.9130
# Group 2 appears to be normally distributed.
# Levene's Test for Equal Variance: W=0.2452, P-value=0.6223
# Groups have approximately equal variances.
# ANOVA F-statistic: 3.9012, P-value: 0.0530
# Fail to reject the null hypothesis: No significant difference among group means.
# <ipython-input-25-824d084d907c>:48: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
# Chi-Square Test for Population Variance:
# ...

# %%
#25.D Write a Python script to perform a Z-test for comparing proportions between two datasets or groups?
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway, levene, shapiro, ttest_ind
from statsmodels.stats.proportion import proportions_ztest

def check_anova_assumptions(*groups):
    """
    Check assumptions for ANOVA: Normality, Independence, and Equal Variance.
    """
    print("Checking ANOVA assumptions:")

    # Normality test (Shapiro-Wilk test)
    for i, group in enumerate(groups):
        stat, p = shapiro(group)
        print(f"Group {i+1} Normality Test: W={stat:.4f}, P-value={p:.4f}")
        if p < 0.05:
            print(f"Group {i+1} is NOT normally distributed.")
        else:
            print(f"Group {i+1} appears to be normally distributed.")

    # Equal Variance Test (Levene's test)
    stat, p = levene(*groups)
    print(f"Levene's Test for Equal Variance: W={stat:.4f}, P-value={p:.4f}")
    if p < 0.05:
        print("Groups do NOT have equal variances (heteroscedasticity detected).")
    else:
        print("Groups have approximately equal variances.")

def one_way_anova(*groups):
    """
    Perform a one-way ANOVA test to compare means between multiple groups and visualize the results.
    """
    check_anova_assumptions(*groups)

    f_stat, p_value = f_oneway(*groups)
    print(f"ANOVA F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference among group means.")

    # Boxplot visualization
    plt.figure(figsize=(8, 5))
    plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
    plt.title("One-Way ANOVA Test: Comparison of Group Means")
    plt.ylabel("Values")
    plt.show()

def perform_t_test(sample1, sample2):
    """
    Perform an independent t-test to compare means of two samples.
    """
    t_stat, p_value = ttest_ind(sample1, sample2)
    print(f"T-Test Statistic: {t_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: The two sample means are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between sample means.")

def perform_variance_test(sample, pop_variance):
    """
    Perform a hypothesis test for population variance using the Chi-square distribution.
    """
    n = len(sample)
    sample_variance = np.var(sample, ddof=1)  # Sample variance
    chi_square_stat = (n - 1) * sample_variance / pop_variance
    p_value = 1 - chi2.cdf(chi_square_stat, df=n-1)  # Upper tail test

    print(f"Chi-square Test Statistic: {chi_square_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: The population variance is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference in population variance.")

def perform_proportion_z_test(count1, nobs1, count2, nobs2):
    """
    Perform a Z-test for comparing proportions between two datasets or groups.
    """
    stat, p_value = proportions_ztest([count1, count2], [nobs1, nobs2])
    print(f"Z-Test for Proportions: Z-statistic={stat:.4f}, P-value={p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: The proportions are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between proportions.")

def simulate_and_test():
    """
    Simulate data from a normal distribution and perform hypothesis testing.
    """
    np.random.seed(42)

    # Simulate random normal data
    sample1 = np.random.normal(loc=50, scale=5, size=30)
    sample2 = np.random.normal(loc=52, scale=5, size=30)

    print("\nIndependent T-Test Results:")
    perform_t_test(sample1, sample2)

    print("\nOne-Way ANOVA Test Results:")
    one_way_anova(sample1, sample2)

    print("\nChi-Square Test for Population Variance:")
    perform_variance_test(sample1, pop_variance=25)  # Assuming population variance = 25

    print("\nZ-Test for Proportions:")
    perform_proportion_z_test(count1=50, nobs1=200, count2=60, nobs2=220)  # Example proportions test

simulate_and_test()
# Out:
# Independent T-Test Results:
# T-Test Statistic: -1.9752, P-value: 0.0530
# Fail to reject the null hypothesis: No significant difference between sample means.
#
# One-Way ANOVA Test Results:
# Checking ANOVA assumptions:
# Group 1 Normality Test: W=0.9751, P-value=0.6868
# Group 1 appears to be normally distributed.
# Group 2 Normality Test: W=0.9837, P-value=0.9130
# Group 2 appears to be normally distributed.
# Levene's Test for Equal Variance: W=0.2452, P-value=0.6223
# Groups have approximately equal variances.
# ANOVA F-statistic: 3.9012, P-value: 0.0530
# Fail to reject the null hypothesis: No significant difference among group means.
# <ipython-input-27-b353849b9a8a>:49: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
# Chi-Square Test for Population Variance:
# ...

# %%
#26.Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results?
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway, levene, shapiro, ttest_ind, f
from statsmodels.stats.proportion import proportions_ztest

def check_anova_assumptions(*groups):
    """
    Check assumptions for ANOVA: Normality, Independence, and Equal Variance.
    """
    print("Checking ANOVA assumptions:")

    # Normality test (Shapiro-Wilk test)
    for i, group in enumerate(groups):
        stat, p = shapiro(group)
        print(f"Group {i+1} Normality Test: W={stat:.4f}, P-value={p:.4f}")
        if p < 0.05:
            print(f"Group {i+1} is NOT normally distributed.")
        else:
            print(f"Group {i+1} appears to be normally distributed.")

    # Equal Variance Test (Levene's test)
    stat, p = levene(*groups)
    print(f"Levene's Test for Equal Variance: W={stat:.4f}, P-value={p:.4f}")
    if p < 0.05:
        print("Groups do NOT have equal variances (heteroscedasticity detected).")
    else:
        print("Groups have approximately equal variances.")

def one_way_anova(*groups):
    """
    Perform a one-way ANOVA test to compare means between multiple groups and visualize the results.
    """
    check_anova_assumptions(*groups)

    f_stat, p_value = f_oneway(*groups)
    print(f"ANOVA F-statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference among group means.")

    # Boxplot visualization
    plt.figure(figsize=(8, 5))
    plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
    plt.title("One-Way ANOVA Test: Comparison of Group Means")
    plt.ylabel("Values")
    plt.show()

def perform_f_test(sample1, sample2):
    """
    Perform an F-test to compare the variances of two datasets and visualize the results.
    """
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)
    f_stat = var1 / var2
    dfn = len(sample1) - 1  # Degrees of freedom numerator
    dfd = len(sample2) - 1  # Degrees of freedom denominator
    p_value = 1 - f.cdf(f_stat, dfn, dfd)

    print(f"F-Test Statistic: {f_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: The variances of the two groups are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference in variances.")

    # Visualization
    plt.figure(figsize=(8, 5))
    plt.hist(sample1, alpha=0.5, label="Sample 1", bins=15, edgecolor="black")
    plt.hist(sample2, alpha=0.5, label="Sample 2", bins=15, edgecolor="black")
    plt.title("Comparison of Variances (F-Test)")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.legend()
    plt.show()

def simulate_and_test():
    """
    Simulate data from a normal distribution and perform hypothesis testing.
    """
    np.random.seed(42)

    # Simulate random normal data
    sample1 = np.random.normal(loc=50, scale=5, size=30)
    sample2 = np.random.normal(loc=52, scale=5, size=30)

    print("\nIndependent T-Test Results:")
    perform_t_test(sample1, sample2)

    print("\nOne-Way ANOVA Test Results:")
    one_way_anova(sample1, sample2)

    print("\nF-Test for Comparing Variances:")
    perform_f_test(sample1, sample2)

    print("\nChi-Square Test for Population Variance:")
    perform_variance_test(sample1, pop_variance=25)  # Assuming population variance = 25

    print("\nZ-Test for Proportions:")
    perform_proportion_z_test(count1=50, nobs1=200, count2=60, nobs2=220)  # Example proportions test

simulate_and_test()
# Out:
# Independent T-Test Results:
# T-Test Statistic: -1.9752, P-value: 0.0530
# Fail to reject the null hypothesis: No significant difference between sample means.
#
# One-Way ANOVA Test Results:
# Checking ANOVA assumptions:
# Group 1 Normality Test: W=0.9751, P-value=0.6868
# Group 1 appears to be normally distributed.
# Group 2 Normality Test: W=0.9837, P-value=0.9130
# Group 2 appears to be normally distributed.
# Levene's Test for Equal Variance: W=0.2452, P-value=0.6223
# Groups have approximately equal variances.
# ANOVA F-statistic: 3.9012, P-value: 0.0530
# Fail to reject the null hypothesis: No significant difference among group means.
# <ipython-input-28-39ea29262e8d>:49: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
# F-Test for Comparing Variances:
# ...

# %%
#27.import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import chi2_contingency, chisquare, chi2, f_oneway, levene, shapiro, ttest_ind, f
from statsmodels.stats.proportion import proportions_ztest

def perform_chi_square_goodness_of_fit(observed, expected):
    """
    Perform a Chi-square goodness-of-fit test.
    """
    chi_stat, p_value = chisquare(observed, expected)
    print(f"Chi-Square Statistic: {chi_stat:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Reject the null hypothesis: The observed data does not fit the expected distribution.")
    else:
        print("Fail to reject the null hypothesis: The observed data fits the expected distribution.")

    # Visualization
    categories = range(len(observed))
    plt.figure(figsize=(8, 5))
    plt.bar(categories, observed, alpha=0.5, label="Observed", color='blue')
    plt.bar(categories, expected, alpha=0.5, label="Expected", color='red')
    plt.xlabel("Categories")
    plt.ylabel("Frequency")
    plt.legend()
    plt.title("Chi-Square Goodness-of-Fit Test")
    plt.show()

def simulate_and_test():
    """
    Simulate data from a normal distribution and perform hypothesis testing.
    """
    np.random.seed(42)

    # Simulate random normal data
    sample1 = np.random.normal(loc=50, scale=5, size=30)
    sample2 = np.random.normal(loc=52, scale=5, size=30)

    print("\nOne-Way ANOVA Test Results:")
    one_way_anova(sample1, sample2)

    print("\nF-Test for Comparing Variances:")
    perform_f_test(sample1, sample2)

    print("\nChi-Square Goodness-of-Fit Test:")
    observed_data = np.random.randint(10, 50, size=5)
    expected_data = np.full(5, np.mean(observed_data))
    perform_chi_square_goodness_of_fit(observed_data, expected_data)

simulate_and_test()
# Out:
# One-Way ANOVA Test Results:
# Checking ANOVA assumptions:
# Group 1 Normality Test: W=0.9751, P-value=0.6868
# Group 1 appears to be normally distributed.
# Group 2 Normality Test: W=0.9837, P-value=0.9130
# Group 2 appears to be normally distributed.
# Levene's Test for Equal Variance: W=0.2452, P-value=0.6223
# Groups have approximately equal variances.
# ANOVA F-statistic: 3.9012, P-value: 0.0530
# Fail to reject the null hypothesis: No significant difference among group means.
# <ipython-input-28-39ea29262e8d>:49: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=[f'Group {i+1}' for i in range(len(groups))])
# F-Test for Comparing Variances:
# F-Test Statistic: 0.9343, P-value: 0.5719
# Fail to reject the null hypothesis: No significant difference in variances.
# Chi-Square Goodness-of-Fit Test:
# ...
